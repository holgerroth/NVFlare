# %% [markdown]
# # Getting Started with NVFlare (PyTorch)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NVIDIA/NVFlare/blob/main/examples/hello-world/hello-pt/hello-pt.ipynb)
#
# NVFlare is an open-source framework that allows researchers and
# data scientists to seamlessly move their machine learning and deep
# learning workflows into a federated paradigm.

# %% [markdown]
# ## Basic Concepts
# At the heart of NVFlare lies the concept of collaboration through
# "tasks." An FL controller assigns tasks (e.g., training on local data) to one or more FL clients, processes returned
# results (e.g., model weight updates), and may assign additional
# tasks based on these results and other factors (e.g., a pre-configured
# number of training rounds). The clients run executors which can listen for tasks and perform the necessary computations locally, such as model training. This task-based interaction repeats
# until the experiment’s objectives are met.
#
# <img src="../../../docs/resources/controller_executor_no_filter.png" alt="NVIDIA FLARE Controller and Executor" width=75% height=75% />

# %% [markdown]
# ## Setup environment

# %% [markdown]
# If running in Google Colab, download the source code for this example:

# %%
# %pip install --ignore-installed blinker

# %%
! npx --yes degit -f NVIDIA/NVFlare/examples/hello-world/hello-pt .

# %% [markdown]
# Install nvflare and dependencies:

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## Federated Averaging with NVFlare
# Given the flexible controller and executor concepts, it is easy to implement different computing & communication patterns with NVFlare, such as [FedAvg](https://proceedings.mlr.press/v54/mcmahan17a?ref=https://githubhelp.com) and [cyclic weight transfer](https://academic.oup.com/jamia/article/25/8/945/4956468).
#
# The controller's `run()` routine is responsible for assigning tasks and processing task results from the Executors.

# %% [markdown]
# ### Server Code
# In federated averaging, the server code is responsible for distributing the global model and aggregating model updates from clients.
#
# First, we provide a robust implementation of the [FedAvg](https://proceedings.mlr.press/v54/mcmahan17a?ref=https://githubhelp.com) algorithm with NVFlare.
#
# The server implements these main steps:
# 1. FL server initializes an initial model.
# 2. For each round (global iteration):
#     - FL server samples available clients.
#     - FL server sends the global model to clients and waits for their updates.
#     - FL server aggregates all the `results` and produces a new global model.
#
# In this example, we will directly use the default federated averaging algorithm provided by NVFlare utilizing the [FedAvgRecipe](https://nvflare.readthedocs.io/en/main/apidocs/nvflare.app_opt.pt.recipes.fedavg.html#nvflare.app_opt.pt.recipes.fedavg.FedAvgRecipe) for PyTorch.
#
# There is no need to defined a customized server code for this example.

# %% [markdown]
# ### Client Code
# We take a CIFAR-10 example directly from [PyTorch website](https://github.com/pytorch/tutorials/blob/main/beginner_source/blitz/cifar10_tutorial.py) with some minor modifications, such as removing comments, move the network to [src/net.py](src/net.py), and add a main method and GPU support. The original code can be found at [cifar10_original.py](../../hello-world/ml-to-fl/pt/code/cifar10_original.py).

# %% [markdown]
# Now, we need to adapt this centralized training code to something that can run in a federated setting.
#
# On the client side, the training workflow is as follows:
# 1. Receive the model from the FL server.
# 2. Perform local training on the received global model
# and/or evaluate the received global model for model
# selection.
# 3. Send the new model back to the FL server.

# %% [markdown]
# Using NVFlare's client API, we can easily adapt machine learning code that was written for centralized training and apply it in a federated scenario.
# For a general use case, there are three essential methods to achieve this using the Client API :
# - `init()`: Initializes NVFlare Client API environment.
# - `receive()`: Receives model from the FL server.
# - `send()`: Sends the model to the FL server.

# %% [markdown]
# With these simple methods, the developers can use the Client API
# to change their centralized training code to an FL scenario with
# five lines of code changes as shown below.
# ```python
#     import nvflare.client as flare
#
#     flare.init() # 1. Initializes NVFlare Client API environment.
#     input_model = flare.receive() # 2. Receives model from the FL server.
#     params = input_model.params # 3. Obtain the required information from the received model.
#
#     # original local training code
#     new_params = local_train(params)
#
#     output_model = flare.FLModel(params=new_params) # 4. Put the results in a new `FLModel`
#     flare.send(output_model) # 5. Sends the model to the FL server.
# ```

# %% [markdown]
# The full client training script is saved in a separate file, e.g. [./src/cifar10_fl.py](./src/cifar10_fl.py) doing CNN training on the [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.

# %% [markdown]
# ## Run an NVFlare Job
# Now that we have defined the FedAvg controller to run our federated compute workflow on the FL server, and our client training script to receive the global models, run local training, and send the results back to the FL server, we can put everything together using NVFlare's Job API.

# %% [markdown]
# #### 1. Define the initial model
# First, we define the global model used to initialize the model on the FL server. See [model.py](model.py).

# %% [markdown]
# ```python
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
#
# class SimpleNetwork(nn.Module):
#     def __init__(self):
#         super(SimpleNetwork, self).__init__()
#         self.conv1 = nn.Conv2d(3, 6, 5)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv2 = nn.Conv2d(6, 16, 5)
#         self.fc1 = nn.Linear(16 * 5 * 5, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, 10)
#
#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = torch.flatten(x, 1)  # flatten all dimensions except batch
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x
# ```

# %% [markdown]
# #### 2. Define a FedJob Recipe

# %%
from model import SimpleNetwork

from nvflare.app_opt.pt.recipes.fedavg import FedAvgRecipe
from nvflare.recipe import SimEnv, add_experiment_tracking

n_clients = 2
num_rounds = 2

recipe = FedAvgRecipe(
    name="hello-pt",
    min_clients=n_clients,
    num_rounds=num_rounds,
    initial_model=SimpleNetwork(),
    train_script="client.py",
)

# %% [markdown]
# #### 3. Add experiment tracking

# %%
add_experiment_tracking(recipe, tracking_type="tensorboard")

# %% [markdown]
# #### 4. Run Job
# Here, we run the job in a simulation environment.

# %%
env = SimEnv(num_clients=n_clients)
run = recipe.execute(env)
print()
print("Job Status is:", run.get_status())
print("Result can be found in :", run.get_result())
print()
# Out:
# 2025-12-15 14:06:14,967 - INFO - model selection weights control: {}
# 2025-12-15 14:06:16,158 - INFO - Tensorboard records can be found in /tmp/nvflare/simulation/hello-pt/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/simulation/hello-pt/server/simulate_job/tb_events`
# 2025-12-15 14:06:16,159 - INFO - Initializing ScatterAndGather workflow for Federated Averaging.
# 2025-12-15 14:06:16,159 - INFO - Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2025-12-15 14:06:16,178 - INFO - Beginning ScatterAndGather training phase.
# 2025-12-15 14:06:16,178 - INFO - Round 0 started.
# 2025-12-15 14:06:21,504 - INFO - start task run() with full path: /tmp/nvflare/simulation/hello-pt/site-1/simulate_job/app_site-1/custom/client.py
# 2025-12-15 14:06:21,506 - INFO - start task run() with full path: /tmp/nvflare/simulation/hello-pt/site-2/simulate_job/app_site-2/custom/client.py
# 2025-12-15 14:06:21,512 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,513 - INFO - ViaDownloader: created ref for target 138910787374128: T0
# 2025-12-15 14:06:21,513 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,514 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,514 - INFO - ViaDownloader: created ref for target 138910787374128: T0
# 2025-12-15 14:06:21,514 - INFO - ViaDownloader: created ref for target 138910787374320: T1
# 2025-12-15 14:06:21,514 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,514 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,515 - INFO - ViaDownloader: created ref for target 138910787374320: T1
# 2025-12-15 14:06:21,515 - INFO - ViaDownloader: created ref for target 138910787374512: T2
# 2025-12-15 14:06:21,515 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,515 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,516 - INFO - ViaDownloader: created ref for target 138910787374512: T2
# 2025-12-15 14:06:21,516 - INFO - ViaDownloader: created ref for target 138910787374704: T3
# 2025-12-15 14:06:21,516 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,516 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,517 - INFO - ViaDownloader: created ref for target 138910787374704: T3
# 2025-12-15 14:06:21,517 - INFO - ViaDownloader: created ref for target 138910787374896: T4
# 2025-12-15 14:06:21,517 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,517 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,517 - INFO - ViaDownloader: created ref for target 138910787374896: T4
# 2025-12-15 14:06:21,518 - INFO - ViaDownloader: created ref for target 138910787375088: T5
# 2025-12-15 14:06:21,518 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,518 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,518 - INFO - ViaDownloader: created ref for target 138910787375088: T5
# 2025-12-15 14:06:21,518 - INFO - ViaDownloader: created ref for target 138910787375280: T6
# 2025-12-15 14:06:21,519 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,519 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,519 - INFO - ViaDownloader: created ref for target 138910787375280: T6
# 2025-12-15 14:06:21,519 - INFO - ViaDownloader: created ref for target 138910787375472: T7
# 2025-12-15 14:06:21,519 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,520 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,520 - INFO - ViaDownloader: created ref for target 138910787375472: T7
# 2025-12-15 14:06:21,520 - INFO - ViaDownloader: created ref for target 138910787375664: T8
# 2025-12-15 14:06:21,520 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,520 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,521 - INFO - ViaDownloader: created ref for target 138910787375664: T8
# 2025-12-15 14:06:21,521 - INFO - ViaDownloader: created ref for target 138910787375856: T9
# 2025-12-15 14:06:21,521 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:06:21,521 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'server.simulate_job', 'ref_id': 'ae8286ca-3d0c-41e3-94b8-03f0b83077eb'}
# 2025-12-15 14:06:21,522 - INFO - ViaDownloader: created ref for target 138910787375856: T9
# 2025-12-15 14:06:21,522 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:06:21,522 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'server.simulate_job', 'ref_id': '124fedb8-2c38-4428-b119-dee218f63f97'}
# 2025-12-15 14:06:21,523 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:06:21,523 - INFO - set transaction info: tx_id='T3063d397-3360-46fa-bd2e-fde4f9cbf65f', ref_id='ae8286ca-3d0c-41e3-94b8-03f0b83077eb' self.num_receivers=1
# 2025-12-15 14:06:21,523 - INFO - set transaction info: tx_id='T9fa84f5d-2cdd-42e3-ac95-39183165a272', ref_id='124fedb8-2c38-4428-b119-dee218f63f97' self.num_receivers=1
# 2025-12-15 14:06:21,525 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:06:21,525 - INFO - trying to download from remote cell for ref={'fqcn': 'server.simulate_job', 'ref_id': 'ae8286ca-3d0c-41e3-94b8-03f0b83077eb'}
# 2025-12-15 14:06:21,525 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:06:21,525 - INFO - trying to download: ref_id='ae8286ca-3d0c-41e3-94b8-03f0b83077eb' fqcn='server.simulate_job'
# 2025-12-15 14:06:21,526 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:06:21,527 - INFO - trying to download from remote cell for ref={'fqcn': 'server.simulate_job', 'ref_id': '124fedb8-2c38-4428-b119-dee218f63f97'}
# 2025-12-15 14:06:21,527 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:06:21,527 - INFO - trying to download: ref_id='124fedb8-2c38-4428-b119-dee218f63f97' fqcn='server.simulate_job'
# 2025-12-15 14:06:21,528 - INFO - created and cached item 0 for site-1.simulate_job: 2315 bytes
# 2025-12-15 14:06:21,528 - INFO - created and cached item 1 for site-1.simulate_job: 539 bytes
# 2025-12-15 14:06:21,529 - INFO - created and cached item 2 for site-1.simulate_job: 10115 bytes
# 2025-12-15 14:06:21,529 - INFO - created and cached item 0 for site-2.simulate_job: 2315 bytes
# 2025-12-15 14:06:21,530 - INFO - created and cached item 3 for site-1.simulate_job: 579 bytes
# 2025-12-15 14:06:21,530 - INFO - created and cached item 1 for site-2.simulate_job: 539 bytes
# 2025-12-15 14:06:21,531 - INFO - created and cached item 4 for site-1.simulate_job: 192515 bytes
# 2025-12-15 14:06:21,532 - INFO - created and cached item 2 for site-2.simulate_job: 10115 bytes
# 2025-12-15 14:06:21,532 - INFO - created and cached item 5 for site-1.simulate_job: 995 bytes
# 2025-12-15 14:06:21,533 - INFO - created and cached item 6 for site-1.simulate_job: 40835 bytes
# 2025-12-15 14:06:21,533 - INFO - created and cached item 7 for site-1.simulate_job: 851 bytes
# 2025-12-15 14:06:21,533 - INFO - created and cached item 8 for site-1.simulate_job: 3875 bytes
# 2025-12-15 14:06:21,534 - INFO - created and cached item 9 for site-1.simulate_job: 555 bytes
# 2025-12-15 14:06:21,534 - INFO - produced 10 items for site-1.simulate_job: 253174 bytes
# 2025-12-15 14:06:21,535 - INFO - created and cached item 3 for site-2.simulate_job: 579 bytes
# 2025-12-15 14:06:21,536 - INFO - created and cached item 4 for site-2.simulate_job: 192515 bytes
# 2025-12-15 14:06:21,536 - INFO - created and cached item 5 for site-2.simulate_job: 995 bytes
# 2025-12-15 14:06:21,536 - INFO - created and cached item 6 for site-2.simulate_job: 40835 bytes
# 2025-12-15 14:06:21,537 - INFO - created and cached item 7 for site-2.simulate_job: 851 bytes
# 2025-12-15 14:06:21,537 - INFO - created and cached item 8 for site-2.simulate_job: 3875 bytes
# 2025-12-15 14:06:21,537 - INFO - created and cached item 9 for site-2.simulate_job: 555 bytes
# 2025-12-15 14:06:21,537 - INFO - produced 10 items for site-2.simulate_job: 253174 bytes
# 2025-12-15 14:06:21,557 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,557 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,558 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,558 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,558 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,558 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,558 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,558 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,559 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,559 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,559 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:06:21,569 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,570 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,570 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,570 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,570 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,571 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,571 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,571 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,571 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,571 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:06:21,572 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:06:21,577 - INFO - downloaded 11 items successfully
# 2025-12-15 14:06:21,578 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T0
# 2025-12-15 14:06:21,578 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,578 - INFO - tid=131002000193344 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,578 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T1
# 2025-12-15 14:06:21,579 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,579 - INFO - tid=131002000193344 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,579 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T2
# 2025-12-15 14:06:21,579 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,579 - INFO - tid=131002000193344 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,582 - INFO - downloaded 11 items successfully
# 2025-12-15 14:06:21,583 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T0
# 2025-12-15 14:06:21,583 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,580 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T3
# 2025-12-15 14:06:21,584 - INFO - tid=128394370643776 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,584 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T1
# 2025-12-15 14:06:21,584 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,584 - INFO - tid=128394370643776 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,585 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T2
# 2025-12-15 14:06:21,585 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,585 - INFO - tid=128394370643776 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,586 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T3
# 2025-12-15 14:06:21,586 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,586 - INFO - tid=131002000193344 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,586 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T4
# 2025-12-15 14:06:21,586 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,587 - INFO - tid=131002000193344 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,587 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T5
# 2025-12-15 14:06:21,587 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,587 - INFO - tid=131002000193344 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,588 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T6
# 2025-12-15 14:06:21,588 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,588 - INFO - tid=131002000193344 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,588 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T7
# 2025-12-15 14:06:21,589 - INFO - trying to get item for item_id='T7' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,586 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,590 - INFO - tid=128394370643776 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,590 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T4
# 2025-12-15 14:06:21,591 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,591 - INFO - tid=128394370643776 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,591 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T5
# 2025-12-15 14:06:21,591 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,591 - INFO - tid=128394370643776 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,592 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T6
# 2025-12-15 14:06:21,592 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,592 - INFO - tid=128394370643776 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,592 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T7
# 2025-12-15 14:06:21,593 - INFO - trying to get item for item_id='T7' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,593 - INFO - tid=131002000193344 found item T7: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,593 - INFO - tid=128394370643776 found item T7: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,593 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T8
# 2025-12-15 14:06:21,593 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T8
# 2025-12-15 14:06:21,593 - INFO - trying to get item for item_id='T8' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,593 - INFO - trying to get item for item_id='T8' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,594 - INFO - tid=131002000193344 found item T8: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,594 - INFO - tid=128394370643776 found item T8: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,594 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T9
# 2025-12-15 14:06:21,594 - INFO - trying to get item for item_id='T9' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,594 - INFO - tid=131002000193344 found item T9: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,596 - INFO - execute for task (train)
# 2025-12-15 14:06:21,597 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T9
# 2025-12-15 14:06:21,597 - INFO - trying to get item for item_id='T9' from type(items)=<class 'dict'>
# 2025-12-15 14:06:21,597 - INFO - tid=128394370643776 found item T9: <class 'numpy.ndarray'>
# 2025-12-15 14:06:21,598 - INFO - send data to peer
# 2025-12-15 14:06:21,598 - INFO - sending payload to peer
# 2025-12-15 14:06:21,599 - INFO - execute for task (train)
# 2025-12-15 14:06:21,600 - INFO - send data to peer
# 2025-12-15 14:06:21,600 - INFO - sending payload to peer
# 2025-12-15 14:06:21,601 - INFO - Waiting for result from peer
# 2025-12-15 14:06:21,602 - INFO - Waiting for result from peer
# 100%|██████████| 170M/170M [00:50<00:00, 3.38MB/s]
# 100%|██████████| 170M/170M [00:50<00:00, 3.35MB/s]
# 2025-12-15 14:07:16,211 - INFO - site = site-2, current_round=0
# 2025-12-15 14:07:16,904 - INFO - site = site-1, current_round=0
# 2025-12-15 14:07:36,512 - INFO - site=site-2, Epoch: 0/2, Iteration: 3124, Loss: 316.594113830477
# 2025-12-15 14:07:36,719 - INFO - site=site-1, Epoch: 0/2, Iteration: 3124, Loss: 320.29634253680706
# 2025-12-15 14:07:55,820 - INFO - site=site-2, Epoch: 1/2, Iteration: 3124, Loss: 264.6165226958692
# 2025-12-15 14:07:55,828 - INFO - Finished Training for site-2
# 2025-12-15 14:07:55,843 - INFO - site: site-2, sending model to server.
# 2025-12-15 14:07:55,995 - INFO - site=site-1, Epoch: 1/2, Iteration: 3124, Loss: 267.7343960516155
# 2025-12-15 14:07:56,000 - INFO - Finished Training for site-1
# 2025-12-15 14:07:56,005 - INFO - site: site-1, sending model to server.
# 2025-12-15 14:07:56,165 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,165 - INFO - ViaDownloader: created ref for target 130997456806480: T0
# 2025-12-15 14:07:56,166 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,166 - INFO - ViaDownloader: created ref for target 130997456809648: T1
# 2025-12-15 14:07:56,166 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,166 - INFO - ViaDownloader: created ref for target 130997456811280: T2
# 2025-12-15 14:07:56,166 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,167 - INFO - ViaDownloader: created ref for target 130997456811568: T3
# 2025-12-15 14:07:56,167 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,167 - INFO - ViaDownloader: created ref for target 130997456811760: T4
# 2025-12-15 14:07:56,167 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,167 - INFO - ViaDownloader: created ref for target 130997456811952: T5
# 2025-12-15 14:07:56,168 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,168 - INFO - ViaDownloader: created ref for target 130997456812144: T6
# 2025-12-15 14:07:56,168 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,168 - INFO - ViaDownloader: created ref for target 130997456812336: T7
# 2025-12-15 14:07:56,169 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,169 - INFO - ViaDownloader: created ref for target 130997456812528: T8
# 2025-12-15 14:07:56,169 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,169 - INFO - ViaDownloader: created ref for target 130997456812720: T9
# 2025-12-15 14:07:56,170 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'site-1.simulate_job', 'ref_id': 'bd551aed-faad-40a2-8cc0-e078dad47519'}
# 2025-12-15 14:07:56,170 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:07:56,171 - INFO - set transaction info: tx_id='Tfcd1c754-aaaf-417e-9f05-33e2b3a686da', ref_id='bd551aed-faad-40a2-8cc0-e078dad47519' self.num_receivers=1
# 2025-12-15 14:07:56,172 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:07:56,173 - INFO - trying to download from remote cell for ref={'fqcn': 'site-1.simulate_job', 'ref_id': 'bd551aed-faad-40a2-8cc0-e078dad47519'}
# 2025-12-15 14:07:56,173 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:07:56,173 - INFO - trying to download: ref_id='bd551aed-faad-40a2-8cc0-e078dad47519' fqcn='site-1.simulate_job'
# 2025-12-15 14:07:56,176 - INFO - created and cached item 0 for server.simulate_job: 2315 bytes
# 2025-12-15 14:07:56,176 - INFO - created and cached item 1 for server.simulate_job: 539 bytes
# 2025-12-15 14:07:56,177 - INFO - created and cached item 2 for server.simulate_job: 10115 bytes
# 2025-12-15 14:07:56,177 - INFO - created and cached item 3 for server.simulate_job: 579 bytes
# 2025-12-15 14:07:56,178 - INFO - created and cached item 4 for server.simulate_job: 192515 bytes
# 2025-12-15 14:07:56,178 - INFO - created and cached item 5 for server.simulate_job: 995 bytes
# 2025-12-15 14:07:56,178 - INFO - created and cached item 6 for server.simulate_job: 40835 bytes
# 2025-12-15 14:07:56,181 - INFO - created and cached item 7 for server.simulate_job: 851 bytes
# 2025-12-15 14:07:56,181 - INFO - created and cached item 8 for server.simulate_job: 3875 bytes
# 2025-12-15 14:07:56,182 - INFO - created and cached item 9 for server.simulate_job: 555 bytes
# 2025-12-15 14:07:56,182 - INFO - produced 10 items for server.simulate_job: 253174 bytes
# 2025-12-15 14:07:56,185 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,185 - INFO - ViaDownloader: created ref for target 128390021149296: T0
# 2025-12-15 14:07:56,185 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,185 - INFO - ViaDownloader: created ref for target 128390021148048: T1
# 2025-12-15 14:07:56,186 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,186 - INFO - ViaDownloader: created ref for target 128390021149872: T2
# 2025-12-15 14:07:56,186 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,186 - INFO - ViaDownloader: created ref for target 128390021150160: T3
# 2025-12-15 14:07:56,186 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,186 - INFO - ViaDownloader: created ref for target 128390021150352: T4
# 2025-12-15 14:07:56,186 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,187 - INFO - ViaDownloader: created ref for target 128390021150544: T5
# 2025-12-15 14:07:56,187 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,187 - INFO - ViaDownloader: created ref for target 128390021150736: T6
# 2025-12-15 14:07:56,187 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,187 - INFO - ViaDownloader: created ref for target 128390021150928: T7
# 2025-12-15 14:07:56,188 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,188 - INFO - ViaDownloader: created ref for target 128390021151120: T8
# 2025-12-15 14:07:56,188 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:56,188 - INFO - ViaDownloader: created ref for target 128390021151312: T9
# 2025-12-15 14:07:56,189 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'site-2.simulate_job', 'ref_id': 'd3a06ad0-bbf5-48c4-a9c0-3bce636dfd35'}
# 2025-12-15 14:07:56,189 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:07:56,190 - INFO - set transaction info: tx_id='Te9f04441-2e5b-4cc2-815f-3bee2b6779da', ref_id='d3a06ad0-bbf5-48c4-a9c0-3bce636dfd35' self.num_receivers=1
# 2025-12-15 14:07:56,192 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:07:56,193 - INFO - trying to download from remote cell for ref={'fqcn': 'site-2.simulate_job', 'ref_id': 'd3a06ad0-bbf5-48c4-a9c0-3bce636dfd35'}
# 2025-12-15 14:07:56,193 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,193 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:07:56,193 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,193 - INFO - trying to download: ref_id='d3a06ad0-bbf5-48c4-a9c0-3bce636dfd35' fqcn='site-2.simulate_job'
# 2025-12-15 14:07:56,193 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,193 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,194 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,194 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,194 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,194 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,194 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,195 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,195 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:07:56,195 - INFO - created and cached item 0 for server.simulate_job: 2315 bytes
# 2025-12-15 14:07:56,196 - INFO - created and cached item 1 for server.simulate_job: 539 bytes
# 2025-12-15 14:07:56,196 - INFO - created and cached item 2 for server.simulate_job: 10115 bytes
# 2025-12-15 14:07:56,196 - INFO - downloaded 11 items successfully
# 2025-12-15 14:07:56,197 - INFO - created and cached item 3 for server.simulate_job: 579 bytes
# 2025-12-15 14:07:56,197 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T0
# 2025-12-15 14:07:56,197 - INFO - created and cached item 4 for server.simulate_job: 192515 bytes
# 2025-12-15 14:07:56,197 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,198 - INFO - tid=138910281741888 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,198 - INFO - created and cached item 5 for server.simulate_job: 995 bytes
# 2025-12-15 14:07:56,198 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T1
# 2025-12-15 14:07:56,198 - INFO - created and cached item 6 for server.simulate_job: 40835 bytes
# 2025-12-15 14:07:56,198 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,198 - INFO - tid=138910281741888 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,198 - INFO - created and cached item 7 for server.simulate_job: 851 bytes
# 2025-12-15 14:07:56,199 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T2
# 2025-12-15 14:07:56,199 - INFO - created and cached item 8 for server.simulate_job: 3875 bytes
# 2025-12-15 14:07:56,199 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,199 - INFO - tid=138910281741888 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,199 - INFO - created and cached item 9 for server.simulate_job: 555 bytes
# 2025-12-15 14:07:56,199 - INFO - produced 10 items for server.simulate_job: 253174 bytes
# 2025-12-15 14:07:56,199 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T3
# 2025-12-15 14:07:56,200 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,200 - INFO - tid=138910281741888 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,200 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T4
# 2025-12-15 14:07:56,200 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,201 - INFO - tid=138910281741888 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,201 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T5
# 2025-12-15 14:07:56,201 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,201 - INFO - tid=138910281741888 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,202 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T6
# 2025-12-15 14:07:56,204 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,205 - INFO - tid=138910281741888 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,206 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T7
# 2025-12-15 14:07:56,206 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,206 - INFO - trying to get item for item_id='T7' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,206 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,206 - INFO - tid=138910281741888 found item T7: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,206 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,206 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T8
# 2025-12-15 14:07:56,207 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,207 - INFO - trying to get item for item_id='T8' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,207 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,207 - INFO - tid=138910281741888 found item T8: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,207 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,207 - INFO - ViaDownloader: tid=138910281741888 recomposing data item T9
# 2025-12-15 14:07:56,207 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,207 - INFO - trying to get item for item_id='T9' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,207 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,208 - INFO - tid=138910281741888 found item T9: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,208 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,208 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:07:56,208 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:07:56,209 - WARNING - Aggregation_weight missing for site-1 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2025-12-15 14:07:56,210 - INFO - downloaded 11 items successfully
# 2025-12-15 14:07:56,210 - INFO - Contribution from site-1 ACCEPTED by the aggregator at round 0.
# 2025-12-15 14:07:56,211 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T0
# 2025-12-15 14:07:56,304 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,305 - INFO - tid=138910290134592 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,306 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T1
# 2025-12-15 14:07:56,306 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,306 - INFO - tid=138910290134592 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,307 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T2
# 2025-12-15 14:07:56,307 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,307 - INFO - tid=138910290134592 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,307 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T3
# 2025-12-15 14:07:56,307 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='748b3c2d-1861-47fb-9f43-58ec1f06826e'
# 2025-12-15 14:07:56,308 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,308 - INFO - tid=138910290134592 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,308 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T4
# 2025-12-15 14:07:56,308 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,308 - INFO - tid=138910290134592 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,309 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T5
# 2025-12-15 14:07:56,309 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,309 - INFO - tid=138910290134592 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,309 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T6
# 2025-12-15 14:07:56,309 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,310 - INFO - tid=138910290134592 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,310 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T7
# 2025-12-15 14:07:56,310 - INFO - trying to get item for item_id='T7' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,310 - INFO - tid=138910290134592 found item T7: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,310 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T8
# 2025-12-15 14:07:56,310 - INFO - trying to get item for item_id='T8' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,310 - INFO - tid=138910290134592 found item T8: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,310 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T9
# 2025-12-15 14:07:56,311 - INFO - trying to get item for item_id='T9' from type(items)=<class 'dict'>
# 2025-12-15 14:07:56,311 - INFO - tid=138910290134592 found item T9: <class 'numpy.ndarray'>
# 2025-12-15 14:07:56,312 - WARNING - Aggregation_weight missing for site-2 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2025-12-15 14:07:56,312 - INFO - Contribution from site-2 ACCEPTED by the aggregator at round 0.
# 2025-12-15 14:07:56,392 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='2b258f81-e3c4-4ab2-ba11-81f896e6bb60'
# 2025-12-15 14:07:56,505 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='2baad34a-c65e-4548-919b-224526ce18f3'
# 2025-12-15 14:07:56,506 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='2baad34a-c65e-4548-919b-224526ce18f3'
# 2025-12-15 14:07:56,704 - INFO - Start aggregation.
# 2025-12-15 14:07:56,706 - INFO - aggregating 2 update(s) at round 0
# 2025-12-15 14:07:56,707 - INFO - End aggregation.
# 2025-12-15 14:07:56,708 - INFO - Start persist model on server.
# 2025-12-15 14:07:56,709 - INFO - End persist model on server.
# 2025-12-15 14:07:56,709 - INFO - Round 0 finished.
# 2025-12-15 14:07:56,795 - INFO - Round 1 started.
# 2025-12-15 14:07:58,315 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,315 - INFO - ViaDownloader: created ref for target 138910792376144: T0
# 2025-12-15 14:07:58,315 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,315 - INFO - ViaDownloader: created ref for target 138910787384112: T1
# 2025-12-15 14:07:58,315 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,315 - INFO - ViaDownloader: created ref for target 138910787386224: T2
# 2025-12-15 14:07:58,316 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,316 - INFO - ViaDownloader: created ref for target 138910787386032: T3
# 2025-12-15 14:07:58,316 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,316 - INFO - ViaDownloader: created ref for target 138910787387280: T4
# 2025-12-15 14:07:58,316 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,316 - INFO - ViaDownloader: created ref for target 138910787382576: T5
# 2025-12-15 14:07:58,316 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,317 - INFO - ViaDownloader: created ref for target 138910787384688: T6
# 2025-12-15 14:07:58,317 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,317 - INFO - ViaDownloader: created ref for target 138910787380656: T7
# 2025-12-15 14:07:58,317 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,317 - INFO - ViaDownloader: created ref for target 138910787381808: T8
# 2025-12-15 14:07:58,317 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,317 - INFO - ViaDownloader: created ref for target 138910787380752: T9
# 2025-12-15 14:07:58,318 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'server.simulate_job', 'ref_id': 'd2a0585b-6b25-4165-9e17-7b92d15dda92'}
# 2025-12-15 14:07:58,318 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:07:58,318 - INFO - set transaction info: tx_id='T8e24cd7d-7d95-4823-942a-c660890110d0', ref_id='d2a0585b-6b25-4165-9e17-7b92d15dda92' self.num_receivers=1
# 2025-12-15 14:07:58,320 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:07:58,320 - INFO - trying to download from remote cell for ref={'fqcn': 'server.simulate_job', 'ref_id': 'd2a0585b-6b25-4165-9e17-7b92d15dda92'}
# 2025-12-15 14:07:58,320 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:07:58,320 - INFO - trying to download: ref_id='d2a0585b-6b25-4165-9e17-7b92d15dda92' fqcn='server.simulate_job'
# 2025-12-15 14:07:58,322 - INFO - created and cached item 0 for site-1.simulate_job: 2315 bytes
# 2025-12-15 14:07:58,322 - INFO - created and cached item 1 for site-1.simulate_job: 539 bytes
# 2025-12-15 14:07:58,322 - INFO - created and cached item 2 for site-1.simulate_job: 10115 bytes
# 2025-12-15 14:07:58,323 - INFO - created and cached item 3 for site-1.simulate_job: 579 bytes
# 2025-12-15 14:07:58,323 - INFO - created and cached item 4 for site-1.simulate_job: 192515 bytes
# 2025-12-15 14:07:58,323 - INFO - created and cached item 5 for site-1.simulate_job: 995 bytes
# 2025-12-15 14:07:58,323 - INFO - created and cached item 6 for site-1.simulate_job: 40835 bytes
# 2025-12-15 14:07:58,324 - INFO - created and cached item 7 for site-1.simulate_job: 851 bytes
# 2025-12-15 14:07:58,324 - INFO - created and cached item 8 for site-1.simulate_job: 3875 bytes
# 2025-12-15 14:07:58,324 - INFO - created and cached item 9 for site-1.simulate_job: 555 bytes
# 2025-12-15 14:07:58,324 - INFO - produced 10 items for site-1.simulate_job: 253174 bytes
# 2025-12-15 14:07:58,329 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,330 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,330 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,330 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,330 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,330 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,330 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,330 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,331 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,331 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,331 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:07:58,332 - INFO - downloaded 11 items successfully
# 2025-12-15 14:07:58,332 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T0
# 2025-12-15 14:07:58,333 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,333 - INFO - tid=131002000193344 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,333 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T1
# 2025-12-15 14:07:58,333 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,333 - INFO - tid=131002000193344 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,333 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T2
# 2025-12-15 14:07:58,333 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,334 - INFO - tid=131002000193344 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,334 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T3
# 2025-12-15 14:07:58,334 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,334 - INFO - tid=131002000193344 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,334 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T4
# 2025-12-15 14:07:58,334 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,334 - INFO - tid=131002000193344 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,335 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T5
# 2025-12-15 14:07:58,335 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,335 - INFO - tid=131002000193344 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,335 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T6
# 2025-12-15 14:07:58,335 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,335 - INFO - tid=131002000193344 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,335 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T7
# 2025-12-15 14:07:58,335 - INFO - trying to get item for item_id='T7' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,336 - INFO - tid=131002000193344 found item T7: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,336 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T8
# 2025-12-15 14:07:58,336 - INFO - trying to get item for item_id='T8' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,336 - INFO - tid=131002000193344 found item T8: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,336 - INFO - ViaDownloader: tid=131002000193344 recomposing data item T9
# 2025-12-15 14:07:58,336 - INFO - trying to get item for item_id='T9' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,336 - INFO - tid=131002000193344 found item T9: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,337 - INFO - execute for task (train)
# 2025-12-15 14:07:58,338 - INFO - send data to peer
# 2025-12-15 14:07:58,338 - INFO - sending payload to peer
# 2025-12-15 14:07:58,338 - INFO - Waiting for result from peer
# 2025-12-15 14:07:58,399 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,400 - INFO - ViaDownloader: created ref for target 138910792376144: T0
# 2025-12-15 14:07:58,400 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,400 - INFO - ViaDownloader: created ref for target 138910787384112: T1
# 2025-12-15 14:07:58,400 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,401 - INFO - ViaDownloader: created ref for target 138910787386224: T2
# 2025-12-15 14:07:58,401 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,401 - INFO - ViaDownloader: created ref for target 138910787386032: T3
# 2025-12-15 14:07:58,402 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,402 - INFO - ViaDownloader: created ref for target 138910787387280: T4
# 2025-12-15 14:07:58,402 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,402 - INFO - ViaDownloader: created ref for target 138910787382576: T5
# 2025-12-15 14:07:58,403 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,403 - INFO - ViaDownloader: created ref for target 138910787384688: T6
# 2025-12-15 14:07:58,403 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,404 - INFO - ViaDownloader: created ref for target 138910787380656: T7
# 2025-12-15 14:07:58,404 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,404 - INFO - ViaDownloader: created ref for target 138910787381808: T8
# 2025-12-15 14:07:58,404 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:07:58,405 - INFO - ViaDownloader: created ref for target 138910787380752: T9
# 2025-12-15 14:07:58,405 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'server.simulate_job', 'ref_id': '25e6f554-e9ee-4d6c-a64f-b3e9f75d6fd1'}
# 2025-12-15 14:07:58,405 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:07:58,406 - INFO - set transaction info: tx_id='T356a82a1-74d9-497f-bd22-ae11731b8be0', ref_id='25e6f554-e9ee-4d6c-a64f-b3e9f75d6fd1' self.num_receivers=1
# 2025-12-15 14:07:58,407 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:07:58,407 - INFO - trying to download from remote cell for ref={'fqcn': 'server.simulate_job', 'ref_id': '25e6f554-e9ee-4d6c-a64f-b3e9f75d6fd1'}
# 2025-12-15 14:07:58,407 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:07:58,407 - INFO - trying to download: ref_id='25e6f554-e9ee-4d6c-a64f-b3e9f75d6fd1' fqcn='server.simulate_job'
# 2025-12-15 14:07:58,409 - INFO - created and cached item 0 for site-2.simulate_job: 2315 bytes
# 2025-12-15 14:07:58,409 - INFO - created and cached item 1 for site-2.simulate_job: 539 bytes
# 2025-12-15 14:07:58,409 - INFO - created and cached item 2 for site-2.simulate_job: 10115 bytes
# 2025-12-15 14:07:58,410 - INFO - created and cached item 3 for site-2.simulate_job: 579 bytes
# 2025-12-15 14:07:58,410 - INFO - created and cached item 4 for site-2.simulate_job: 192515 bytes
# 2025-12-15 14:07:58,410 - INFO - created and cached item 5 for site-2.simulate_job: 995 bytes
# 2025-12-15 14:07:58,411 - INFO - created and cached item 6 for site-2.simulate_job: 40835 bytes
# 2025-12-15 14:07:58,411 - INFO - created and cached item 7 for site-2.simulate_job: 851 bytes
# 2025-12-15 14:07:58,411 - INFO - created and cached item 8 for site-2.simulate_job: 3875 bytes
# 2025-12-15 14:07:58,411 - INFO - created and cached item 9 for site-2.simulate_job: 555 bytes
# 2025-12-15 14:07:58,412 - INFO - produced 10 items for site-2.simulate_job: 253174 bytes
# 2025-12-15 14:07:58,417 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,417 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,417 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,417 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,417 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,418 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,418 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,418 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,418 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,418 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:07:58,418 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:07:58,419 - INFO - downloaded 11 items successfully
# 2025-12-15 14:07:58,420 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T0
# 2025-12-15 14:07:58,420 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,420 - INFO - tid=128394370643776 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,420 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T1
# 2025-12-15 14:07:58,420 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,420 - INFO - tid=128394370643776 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,420 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T2
# 2025-12-15 14:07:58,421 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,421 - INFO - tid=128394370643776 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,421 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T3
# 2025-12-15 14:07:58,421 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,421 - INFO - tid=128394370643776 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,421 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T4
# 2025-12-15 14:07:58,421 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,421 - INFO - tid=128394370643776 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,422 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T5
# 2025-12-15 14:07:58,422 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,422 - INFO - tid=128394370643776 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,422 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T6
# 2025-12-15 14:07:58,422 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:07:58,422 - INFO - tid=128394370643776 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:07:58,422 - INFO - ViaDownloader: tid=128394370643776 recomposing data item T7
# ...
# 2025-12-15 14:08:37,379 - INFO - ViaDownloader: created ref for target 130997456810032: T7
# 2025-12-15 14:08:37,379 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,379 - INFO - ViaDownloader: created ref for target 130997456807536: T8
# 2025-12-15 14:08:37,380 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,380 - INFO - ViaDownloader: created ref for target 130997456811664: T9
# 2025-12-15 14:08:37,380 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'site-1.simulate_job', 'ref_id': 'e13accbd-3453-4d6b-8e46-0e6d3486348a'}
# 2025-12-15 14:08:37,381 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:08:37,381 - INFO - set transaction info: tx_id='T7d4c42a1-cdff-4fc8-95c2-468edf2818ae', ref_id='e13accbd-3453-4d6b-8e46-0e6d3486348a' self.num_receivers=1
# 2025-12-15 14:08:37,383 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:08:37,383 - INFO - trying to download from remote cell for ref={'fqcn': 'site-1.simulate_job', 'ref_id': 'e13accbd-3453-4d6b-8e46-0e6d3486348a'}
# 2025-12-15 14:08:37,383 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:08:37,384 - INFO - trying to download: ref_id='e13accbd-3453-4d6b-8e46-0e6d3486348a' fqcn='site-1.simulate_job'
# 2025-12-15 14:08:37,386 - INFO - created and cached item 0 for server.simulate_job: 2315 bytes
# 2025-12-15 14:08:37,389 - INFO - created and cached item 1 for server.simulate_job: 539 bytes
# 2025-12-15 14:08:37,389 - INFO - created and cached item 2 for server.simulate_job: 10115 bytes
# 2025-12-15 14:08:37,390 - INFO - created and cached item 3 for server.simulate_job: 579 bytes
# 2025-12-15 14:08:37,391 - INFO - created and cached item 4 for server.simulate_job: 192515 bytes
# 2025-12-15 14:08:37,391 - INFO - created and cached item 5 for server.simulate_job: 995 bytes
# 2025-12-15 14:08:37,392 - INFO - created and cached item 6 for server.simulate_job: 40835 bytes
# 2025-12-15 14:08:37,392 - INFO - created and cached item 7 for server.simulate_job: 851 bytes
# 2025-12-15 14:08:37,392 - INFO - created and cached item 8 for server.simulate_job: 3875 bytes
# 2025-12-15 14:08:37,393 - INFO - created and cached item 9 for server.simulate_job: 555 bytes
# 2025-12-15 14:08:37,393 - INFO - produced 10 items for server.simulate_job: 253174 bytes
# 2025-12-15 14:08:37,400 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,401 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,401 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,401 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,401 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,402 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,402 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,402 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,403 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,403 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,403 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:08:37,405 - INFO - downloaded 11 items successfully
# 2025-12-15 14:08:37,406 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T0
# 2025-12-15 14:08:37,406 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,406 - INFO - tid=138910290134592 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,407 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T1
# 2025-12-15 14:08:37,407 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,407 - INFO - tid=138910290134592 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,407 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T2
# 2025-12-15 14:08:37,408 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,408 - INFO - tid=138910290134592 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,408 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T3
# 2025-12-15 14:08:37,409 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,409 - INFO - tid=138910290134592 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,409 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T4
# 2025-12-15 14:08:37,409 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,410 - INFO - tid=138910290134592 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,410 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T5
# 2025-12-15 14:08:37,410 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,411 - INFO - tid=138910290134592 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,411 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T6
# 2025-12-15 14:08:37,411 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,412 - INFO - tid=138910290134592 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,412 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T7
# 2025-12-15 14:08:37,412 - INFO - trying to get item for item_id='T7' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,412 - INFO - tid=138910290134592 found item T7: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,413 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T8
# 2025-12-15 14:08:37,413 - INFO - trying to get item for item_id='T8' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,413 - INFO - tid=138910290134592 found item T8: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,413 - INFO - ViaDownloader: tid=138910290134592 recomposing data item T9
# 2025-12-15 14:08:37,414 - INFO - trying to get item for item_id='T9' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,414 - INFO - tid=138910290134592 found item T9: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,415 - WARNING - validation metric not existing in site-1
# 2025-12-15 14:08:37,416 - WARNING - Aggregation_weight missing for site-1 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2025-12-15 14:08:37,417 - INFO - Contribution from site-1 ACCEPTED by the aggregator at round 1.
# 2025-12-15 14:08:37,529 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='a39fa16f-6baa-4f6d-a325-04e890af3675'
# 2025-12-15 14:08:37,548 - INFO - site=site-2, Epoch: 1/2, Iteration: 3124, Loss: 240.54234040156007
# 2025-12-15 14:08:37,550 - INFO - Finished Training for site-2
# 2025-12-15 14:08:37,553 - INFO - site: site-2, sending model to server.
# 2025-12-15 14:08:37,957 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,957 - INFO - ViaDownloader: created ref for target 128390021149104: T0
# 2025-12-15 14:08:37,957 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,957 - INFO - ViaDownloader: created ref for target 128390021146704: T1
# 2025-12-15 14:08:37,957 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,957 - INFO - ViaDownloader: created ref for target 128390021149488: T2
# 2025-12-15 14:08:37,957 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,958 - INFO - ViaDownloader: created ref for target 128390021152656: T3
# 2025-12-15 14:08:37,958 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,958 - INFO - ViaDownloader: created ref for target 128390021151408: T4
# 2025-12-15 14:08:37,958 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,958 - INFO - ViaDownloader: created ref for target 128390021151216: T5
# 2025-12-15 14:08:37,958 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,958 - INFO - ViaDownloader: created ref for target 128390021151024: T6
# 2025-12-15 14:08:37,959 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,959 - INFO - ViaDownloader: created ref for target 128390021150832: T7
# 2025-12-15 14:08:37,959 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,959 - INFO - ViaDownloader: created ref for target 128390021150640: T8
# 2025-12-15 14:08:37,959 - INFO - using download decompose: max_chunk_size=2097152
# 2025-12-15 14:08:37,959 - INFO - ViaDownloader: created ref for target 128390021150448: T9
# 2025-12-15 14:08:37,960 - INFO - ViaDownloader: created download ref for target type NumpyArrayDecomposer: ref={'fqcn': 'site-2.simulate_job', 'ref_id': 'ef4ba964-dfa8-4cbd-bbc2-4a510e4e4890'}
# 2025-12-15 14:08:37,960 - INFO - ViaDownloader: finalizing download tx
# 2025-12-15 14:08:37,960 - INFO - set transaction info: tx_id='Td78ee465-072d-4a06-a01f-0a937799e159', ref_id='ef4ba964-dfa8-4cbd-bbc2-4a510e4e4890' self.num_receivers=1
# 2025-12-15 14:08:37,961 - INFO - ViaDownloader: pre-processing datum datum.dot=3 before recompose
# 2025-12-15 14:08:37,961 - INFO - trying to download from remote cell for ref={'fqcn': 'site-2.simulate_job', 'ref_id': 'ef4ba964-dfa8-4cbd-bbc2-4a510e4e4890'}
# 2025-12-15 14:08:37,961 - INFO - DOWNLOAD_REQ_TIMEOUT=10.0
# 2025-12-15 14:08:37,962 - INFO - trying to download: ref_id='ef4ba964-dfa8-4cbd-bbc2-4a510e4e4890' fqcn='site-2.simulate_job'
# 2025-12-15 14:08:37,963 - INFO - created and cached item 0 for server.simulate_job: 2315 bytes
# 2025-12-15 14:08:37,963 - INFO - created and cached item 1 for server.simulate_job: 539 bytes
# 2025-12-15 14:08:37,963 - INFO - created and cached item 2 for server.simulate_job: 10115 bytes
# 2025-12-15 14:08:37,964 - INFO - created and cached item 3 for server.simulate_job: 579 bytes
# 2025-12-15 14:08:37,964 - INFO - created and cached item 4 for server.simulate_job: 192515 bytes
# 2025-12-15 14:08:37,964 - INFO - created and cached item 5 for server.simulate_job: 995 bytes
# 2025-12-15 14:08:37,964 - INFO - created and cached item 6 for server.simulate_job: 40835 bytes
# 2025-12-15 14:08:37,965 - INFO - created and cached item 7 for server.simulate_job: 851 bytes
# 2025-12-15 14:08:37,965 - INFO - created and cached item 8 for server.simulate_job: 3875 bytes
# 2025-12-15 14:08:37,965 - INFO - created and cached item 9 for server.simulate_job: 555 bytes
# 2025-12-15 14:08:37,965 - INFO - produced 10 items for server.simulate_job: 253174 bytes
# 2025-12-15 14:08:37,970 - INFO - item 0 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,970 - INFO - item 1 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,970 - INFO - item 2 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - item 3 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - item 4 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - item 5 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - item 6 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - item 7 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - item 8 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - item 9 was received by 1 sites - clear cache
# 2025-12-15 14:08:37,971 - INFO - object has been downloaded to all 1 sites - clear cache
# 2025-12-15 14:08:37,972 - INFO - downloaded 11 items successfully
# 2025-12-15 14:08:37,973 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T0
# 2025-12-15 14:08:37,973 - INFO - trying to get item for item_id='T0' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,973 - INFO - tid=138910239778368 found item T0: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,973 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T1
# 2025-12-15 14:08:37,973 - INFO - trying to get item for item_id='T1' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,974 - INFO - tid=138910239778368 found item T1: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,974 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T2
# 2025-12-15 14:08:37,974 - INFO - trying to get item for item_id='T2' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,974 - INFO - tid=138910239778368 found item T2: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,974 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T3
# 2025-12-15 14:08:37,974 - INFO - trying to get item for item_id='T3' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,974 - INFO - tid=138910239778368 found item T3: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,974 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T4
# 2025-12-15 14:08:37,975 - INFO - trying to get item for item_id='T4' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,975 - INFO - tid=138910239778368 found item T4: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,975 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T5
# 2025-12-15 14:08:37,975 - INFO - trying to get item for item_id='T5' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,975 - INFO - tid=138910239778368 found item T5: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,975 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T6
# 2025-12-15 14:08:37,975 - INFO - trying to get item for item_id='T6' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,976 - INFO - tid=138910239778368 found item T6: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,976 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T7
# 2025-12-15 14:08:37,976 - INFO - trying to get item for item_id='T7' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,976 - INFO - tid=138910239778368 found item T7: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,976 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T8
# 2025-12-15 14:08:37,976 - INFO - trying to get item for item_id='T8' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,976 - INFO - tid=138910239778368 found item T8: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,977 - INFO - ViaDownloader: tid=138910239778368 recomposing data item T9
# 2025-12-15 14:08:37,977 - INFO - trying to get item for item_id='T9' from type(items)=<class 'dict'>
# 2025-12-15 14:08:37,977 - INFO - tid=138910239778368 found item T9: <class 'numpy.ndarray'>
# 2025-12-15 14:08:37,978 - WARNING - validation metric not existing in site-2
# 2025-12-15 14:08:37,978 - WARNING - Aggregation_weight missing for site-2 and set to default value, 1.0 This kind of message will show 10 times at most.
# 2025-12-15 14:08:37,978 - INFO - Contribution from site-2 ACCEPTED by the aggregator at round 1.
# 2025-12-15 14:08:38,057 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='d764074f-d707-4a52-b47a-eb727c477879'
# 2025-12-15 14:08:38,170 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='d2d1aaa8-ba9e-4d80-b78c-2edb564c72eb'
# 2025-12-15 14:08:38,170 - INFO - ViaDownloader: deleting download transaction associated with msg_root_id='d2d1aaa8-ba9e-4d80-b78c-2edb564c72eb'
# 2025-12-15 14:08:38,327 - INFO - Start aggregation.
# 2025-12-15 14:08:38,328 - INFO - aggregating 2 update(s) at round 1
# 2025-12-15 14:08:38,330 - INFO - End aggregation.
# 2025-12-15 14:08:38,331 - INFO - Start persist model on server.
# 2025-12-15 14:08:38,334 - INFO - End persist model on server.
# 2025-12-15 14:08:38,335 - INFO - Round 1 finished.
# 2025-12-15 14:08:38,416 - INFO - Finished ScatterAndGather Training.
# 2025-12-15 14:08:39,541 - WARNING - ask to stop job: reason: END_RUN received
# 2025-12-15 14:08:39,683 - WARNING - request to stop the job for reason END_RUN received
# 2025-12-15 14:08:40,067 - WARNING - ask to stop job: reason: END_RUN received
# 2025-12-15 14:08:40,555 - WARNING - request to stop the job for reason END_RUN received
#
# Note, get_status returns None in SimEnv. The simulation logs can be found at /tmp/nvflare/simulation/hello-pt
# Job Status is: None
# Result can be found in : /tmp/nvflare/simulation/hello-pt

# %% [markdown]
# #### 5. Visualize the Training
# You can use TensorBoard to show the experiment tracking curves by running
#
# ```bash
# tensorboard --bind_all --logdir /tmp/nvflare/simulation/hello-pt
# ```
# in another terminal or directly show the training curves in the next notebook cell.

# %%
# %load_ext tensorboard
# %tensorboard --bind_all --logdir /tmp/nvflare/simulation/hello-pt
# Out:
#       <iframe id="tensorboard-frame-90303482d377215e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-90303482d377215e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
