# %% [markdown]
# # Federated Learning with Differential Privacy
#
# Please make sure you set up a virtual environment and follow [example root readme](../../README.md) before starting this notebook.
# Then, install the requirements.
#
# <div class="alert alert-block alert-info"> <b>NOTE</b> Some of the cells below generate long text output.  We're using <pre>%%capture --no-display --no-stderr cell_output</pre> to suppress this output.  Comment or delete this line in the cells below to restore full output.</div>

# %%
# %%capture --no-display --no-stderr cell_output
import sys
# !{sys.executable} -m pip install -r requirements.txt

# %% [markdown]
# ### Differential Privacy (DP)
# [Differential Privacy (DP)](https://arxiv.org/abs/1910.00962) [1] is a rigorous mathematical framework designed to provide strong privacy guarantees when handling sensitive data. In the context of Federated Learning (FL), DP plays a crucial role in safeguarding user information by introducing randomness into the training process. Specifically, it ensures privacy by adding carefully calibrated noise to the model updates—such as gradients or weights—before they are transmitted from clients to the central server. This obfuscation mechanism makes it statistically difficult to infer whether any individual data point contributed to a particular update, thereby protecting user-specific information.
#
# By integrating DP into FL, even if an adversary gains access to the aggregated updates or models, the added noise prevents them from accurately deducing sensitive details about any individual client's data. Common approaches include
#
# 1. **Local Differential Privacy (LDP)**, where noise is added directly on the client side before updates are sent
# 2. **Global Differential Privacy (GDP)**, where noise is injected after aggregation at the server.
#
# The balance between privacy and model utility is typically managed through a privacy budget (ϵ), which quantifies the trade-off between the level of noise added and the resulting model accuracy.
#
#
# As a first example, we show you how to add **local** DP filters to your FL training in NVFlare. Here, we use the "Sparse Vector Technique", i.e. the [SVTPrivacy](https://nvflare.readthedocs.io/en/main/apidocs/nvflare.app_common.filters.svt_privacy.html) protocol, as utilized in [Li et al. 2019](https://arxiv.org/abs/1910.00962) [1] (see [Lyu et al. 2016](https://arxiv.org/abs/1603.01699) [2] for more information).
#
# DP is added as an NVFlare `Filter` using the [FedJob API](https://nvflare.readthedocs.io/en/main/programming_guide/fed_job_api.html#fedjob-api) you should have seen in prior chapters.

# %% [markdown]
# #### Sparse Vector Technique
#
# The [Sparse Vector Technique](https://arxiv.org/abs/1603.01699) (SVT) enhances privacy by applying noise and thresholding to a randomly selected subset of model weights or updates, $x$. The process consists of two main steps:
#
# 1. **Noise Addition:** Laplace noise is added to the absolute value of the selected weights:
#
# $abs(x)+Lap(s)$
#
# 2. **Thresholding and Clipping:** The noisy values are clipped within a predefined range $[−γ,γ]$ and shared only if they meet a thresholding condition:
#
# $clip(x+Lap(s),γ)$
#
# Here, $abs(x)$ represents the absolute value, $Lap(s)$ is noise sampled from the Laplace distribution, $γ$ is the predefined threshold, and $clip(x,γ)$ ensures values remain within the specified range.
#
# The experimental results show that there is a tradeoff between model performance and privacy preservation, where stronger privacy guarantees may impact the model performance more severly.

# %% [markdown]
# ## Run experiments with FL simulator
# For simplicity, we focus on training a simple federated CNN for CIFAR-10 classification (see its definition in [net.py](src/net.py)). FL simulator is used for running the FL experiments.
#
# The experiments are separated into three parts
#
# 1. Train a model using the FedAvg algorithm with four clients without DP.
# 2. Train the same model using DP added as an NVFlare `Filter`.
# 3. Train the same model using [Opacus'](https://opacus.ai) PrivacyEngine on the client to implementemt local [DP-SGD](https://arxiv.org/abs/1607.00133) [3]. In this case, DP noise is added during each optimization step of the local training and we can skip the additional DP filter.

# %% [markdown]
# #### 0. Download the CIFAR-10 data
# First, we download the CIFAR-10 dataset to avoid clients overwriting each other's local dataset during this simulation.

# %%
import torchvision
DATASET_PATH = "/tmp/nvflare/data"
torchvision.datasets.CIFAR10(root=DATASET_PATH, download=True)

# %% [markdown]
# ## 1. Train without DP
# #### 1.1 Define a FedJob
# The `FedJob` is used to define how controllers and executors are placed within a federated job using the `to(object, target)` routine.
#
# Here we use a PyTorch `BaseFedJob`, where we can define the job name and the initial global model.
# The `BaseFedJob` automatically configures components for model persistence, model selection, and TensorBoard streaming for convenience.

# %%
from src.net import Net

from nvflare.app_common.workflows.fedavg import FedAvg
from nvflare.app_opt.pt.job_config.base_fed_job import BaseFedJob
from nvflare.job_config.script_runner import ScriptRunner

job = BaseFedJob(
    name="cifar10_fedavg",
    initial_model=Net(),
)

# %% [markdown]
# #### 1.2 Define the Controller Workflow
# Define the controller workflow and send it to the server. For simplicity, we will run the simulation only for a few round but you can increase it for the models to converge.

# %%
n_clients = 2

controller = FedAvg(
    num_clients=n_clients,
    num_rounds=30,  # 30 rounds should converge
)
job.to(controller, "server")

# %% [markdown]
# That completes the components that need to be defined on the server.

# %% [markdown]
# #### 1.3 Add clients
# Next, we can use the `ScriptRunner` and send it to each of the clients to run our training script.
#
# Note that our script could have additional input arguments, such as batch size or data path, but we don't use them here for simplicity.

# %%
for i in range(n_clients):
    runner = ScriptRunner(
        script="src/cifar10_fl.py"
    )
    job.to(runner, f"site-{i+1}")

# %% [markdown]
# That's it!
#
# #### 1.4 Optionally export the job
# Now, we could export the job and submit it to a real NVFlare deployment using the [Admin client](https://nvflare.readthedocs.io/en/main/real_world_fl/operation.html) or [FLARE API](https://nvflare.readthedocs.io/en/main/real_world_fl/flare_api.html).

# %%
job.export_job("job_configs")

# %% [markdown]
# #### 1.5 Run FL Simulation
# Finally, we can run our FedJob in simulation using NVFlare's [simulator](https://nvflare.readthedocs.io/en/main/user_guide/nvflare_cli/fl_simulator.html) under the hood.
#
# The results will be saved in the specified `workdir`.

# %%
job.simulator_run(f"/tmp/nvflare/{job.name}")

# %% [markdown]
# ## 2. Add DP as an NVFlare Filter
# #### 2.1 Run FL Simulation with DP
# Run the FL simulator with two clients for federated learning with differential privacy. The key now is to add a filter to each client that applies DP before sending the model updates back to the server
# using the `job.to()` method.
#
# Let's create a new FedJob with the DP add through the [SVTPrivacy](https://nvflare.readthedocs.io/en/main/apidocs/nvflare.app_common.filters.html#nvflare.app_common.filters.SVTPrivacy) Filter implementing the **sparse vector technique** for differential privacy [[2]](https://arxiv.org/abs/1603.01699). Note that the epsilon used here is different from the epsilon defining the privacy budget in DP. See [[1]](https://arxiv.org/abs/1910.00962), [[2]](https://arxiv.org/abs/1603.01699) for more details on its usage.
#
# > **Note:** Use `filter_type=FilterType.TASK_RESULT` as we are adding the filter on top of the model updates after local training.
# >
# > Furthermore, this filter was developed for use with weight differences. So, we use `params_transfer_type=TransferType.DIFF` here when specifying the `ScriptRunner`.

# %%
from nvflare import FilterType
from nvflare.client.config import TransferType
from nvflare.app_common.filters import SVTPrivacy

# Create BaseFedJob with the initial model
job = BaseFedJob(
  name="cifar10_fedavg_dp",
  initial_model=Net(),
)

# Define the controller and send to server
controller = FedAvg(
    num_clients=n_clients,
    num_rounds=100,  # 100 rounds should converge
)
job.to_server(controller)

# Add clients
for i in range(n_clients):
    runner = ScriptRunner(
        script="src/cifar10_fl.py",
        params_transfer_type=TransferType.DIFF
    )
    job.to(runner, f"site-{i+1}")

    # add privacy filter.
    dp_filter = SVTPrivacy(fraction=0.9, epsilon=0.1, noise_var=0.1, gamma=1e-5)
    job.to(dp_filter, f"site-{i+1}", tasks=["train"], filter_type=FilterType.TASK_RESULT)

# Optionally export the configuration
job.export_job("job_configs")

# %% [markdown]
# Next, start the training

# %%
job.simulator_run(f"/tmp/nvflare/{job.name}")

# %% [markdown]
# > **Note:** you can also try adding or combining the filters with other privacy filters or customize them. For example, use the [PercentilePrivacy](https://nvflare.readthedocs.io/en/main/apidocs/nvflare.app_common.filters.html#nvflare.app_common.filters.PercentilePrivacy) filter based on Shokri and Shmatikov ([Privacy-preserving deep learning, CCS '15](https://dl.acm.org/doi/abs/10.1145/2810103.2813687)) or [ExcludeVars](https://nvflare.readthedocs.io/en/main/apidocs/nvflare.app_common.filters.html#nvflare.app_common.filters.ExcludeVars) filter to exclude variables that shouldn't be shared with the server.

# %% [markdown]
# ## 3. Run DP-SGD with Privacy Budgeting during local training
# To implement local DP-SGD during client training, we can simply use [Opacus' PrivacyEngine](https://opacus.ai/). For that, we need to modify our training script to add the privacy engine and apply it to our optimizer and data loaders. For example:
# ```
# # Add PrivacyEngine
# privacy_engine = PrivacyEngine()
# model, optimizer, data_loader = privacy_engine.make_private_with_epsilon(
#     module=net,
#     optimizer=optimizer,
#     data_loader=trainloader,
#     target_epsilon=50.0,
#     ...
# )
# ```

# %% [markdown]
# The remaining code is as usual. To enable it, we need to add the `--target_epsilon` argument to our [training script](src/cifar10_fl.py) when using the `ScriptRunner`. We follow the [Opacus example](https://opacus.ai/tutorials/building_image_classifier) and use an epsilon of 50 for training a CIFAR-10 classifier.

# %%
# Create BaseFedJob with the initial model
job = BaseFedJob(
  name="cifar10_fedavg_dpsgd",
  initial_model=Net(),
)

# Define the controller and send to server
controller = FedAvg(
    num_clients=n_clients,
    num_rounds=30,  # 30 rounds should converge
)
job.to_server(controller)

# Add clients
for i in range(n_clients):
    runner = ScriptRunner(
        script="src/cifar10_fl.py",
        script_args="--target_epsilon=50.0",  # lower epsilon will increase privacy but impact accuracy more
        params_transfer_type=TransferType.DIFF
    )
    job.to(runner, f"site-{i+1}")

# Optionally export the configuration
job.export_job("job_configs")

# %% [markdown]
# Again, we can start the training using the simulator call.

# %%
job.simulator_run(f"/tmp/nvflare/{job.name}")
# Out:
# 2025-03-02 23:29:52,345 - IntimeModelSelector - INFO - model selection weights control: {}
# 2025-03-02 23:29:53,659 - TBAnalyticsReceiver - INFO - Tensorboard records can be found in /tmp/nvflare/cifar10_fedavg_dpsgd/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/cifar10_fedavg_dpsgd/server/simulate_job/tb_events`
# 2025-03-02 23:29:53,661 - FedAvg - INFO - Initializing BaseModelController workflow.
# 2025-03-02 23:29:53,661 - FedAvg - INFO - Beginning model controller run.
# 2025-03-02 23:29:53,662 - FedAvg - INFO - Start FedAvg.
# 2025-03-02 23:29:53,662 - FedAvg - INFO - loading initial model from persistor
# 2025-03-02 23:29:53,662 - PTFileModelPersistor - INFO - Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2025-03-02 23:29:53,663 - FedAvg - INFO - Round 0 started.
# 2025-03-02 23:29:53,664 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:29:53,664 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:29:58,390 - TaskScriptRunner - INFO - start task run() with full path: /tmp/nvflare/cifar10_fedavg_dpsgd/site-1/simulate_job/app_site-1/custom/src/cifar10_fl.py
# 2025-03-02 23:29:58,412 - TaskScriptRunner - INFO - start task run() with full path: /tmp/nvflare/cifar10_fedavg_dpsgd/site-2/simulate_job/app_site-2/custom/src/cifar10_fl.py
# 2025-03-02 23:29:58,434 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:29:58,436 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:29:58,437 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:29:58,439 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:29:58,452 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:29:58,454 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:29:58,455 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:29:58,477 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:30:00,510 - TaskScriptRunner - INFO - Running on device cuda
# 2025-03-02 23:30:00,527 - TaskScriptRunner - INFO - Running on device cuda
# 2025-03-02 23:30:01,999 - TaskScriptRunner - INFO - Adding privacy engine with epsilon=50.0, delta=1e-05
# 2025-03-02 23:30:02,059 - TaskScriptRunner - INFO - Adding privacy engine with epsilon=50.0, delta=1e-05
# 2025-03-02 23:31:24,902 - TaskScriptRunner - INFO - current_round=0, total_rounds=30
# 2025-03-02 23:31:24,934 - TaskScriptRunner - INFO - current_round=0, total_rounds=30
# 2025-03-02 23:31:32,429 - TaskScriptRunner - INFO - [1,   100] loss: 2.300
# 2025-03-02 23:31:32,563 - TaskScriptRunner - INFO - [1,   100] loss: 2.300
# 2025-03-02 23:31:32,681 - TaskScriptRunner - INFO - Training with privacy (ε = 8.52, δ = 1e-05)
# 2025-03-02 23:31:32,816 - TaskScriptRunner - INFO - Training with privacy (ε = 8.52, δ = 1e-05)
# 2025-03-02 23:31:39,002 - TaskScriptRunner - INFO - [1,   200] loss: 2.267
# 2025-03-02 23:31:39,088 - TaskScriptRunner - INFO - [1,   200] loss: 2.269
# 2025-03-02 23:31:39,348 - TaskScriptRunner - INFO - Training with privacy (ε = 9.32, δ = 1e-05)
# 2025-03-02 23:31:39,413 - TaskScriptRunner - INFO - Training with privacy (ε = 9.32, δ = 1e-05)
# 2025-03-02 23:31:45,687 - TaskScriptRunner - INFO - [1,   300] loss: 2.183
# 2025-03-02 23:31:45,783 - TaskScriptRunner - INFO - [1,   300] loss: 2.198
# 2025-03-02 23:31:45,960 - TaskScriptRunner - INFO - Training with privacy (ε = 9.91, δ = 1e-05)
# 2025-03-02 23:31:46,046 - TaskScriptRunner - INFO - Training with privacy (ε = 9.91, δ = 1e-05)
# 2025-03-02 23:31:52,378 - TaskScriptRunner - INFO - [1,   400] loss: 2.106
# 2025-03-02 23:31:52,489 - TaskScriptRunner - INFO - [1,   400] loss: 2.117
# 2025-03-02 23:31:52,856 - TaskScriptRunner - INFO - Training with privacy (ε = 10.41, δ = 1e-05)
# 2025-03-02 23:31:52,950 - TaskScriptRunner - INFO - Training with privacy (ε = 10.41, δ = 1e-05)
# 2025-03-02 23:31:59,156 - TaskScriptRunner - INFO - [1,   500] loss: 2.079
# 2025-03-02 23:31:59,289 - TaskScriptRunner - INFO - [1,   500] loss: 2.073
# 2025-03-02 23:31:59,454 - TaskScriptRunner - INFO - Training with privacy (ε = 10.85, δ = 1e-05)
# 2025-03-02 23:31:59,594 - TaskScriptRunner - INFO - Training with privacy (ε = 10.85, δ = 1e-05)
# 2025-03-02 23:32:05,734 - TaskScriptRunner - INFO - [1,   600] loss: 2.081
# 2025-03-02 23:32:05,937 - TaskScriptRunner - INFO - [1,   600] loss: 2.070
# 2025-03-02 23:32:06,075 - TaskScriptRunner - INFO - Training with privacy (ε = 11.25, δ = 1e-05)
# 2025-03-02 23:32:06,278 - TaskScriptRunner - INFO - Training with privacy (ε = 11.25, δ = 1e-05)
# 2025-03-02 23:32:12,065 - TaskScriptRunner - INFO - [1,   700] loss: 2.018
# 2025-03-02 23:32:12,551 - TaskScriptRunner - INFO - Training with privacy (ε = 11.61, δ = 1e-05)
# 2025-03-02 23:32:12,648 - TaskScriptRunner - INFO - [1,   700] loss: 2.028
# 2025-03-02 23:32:13,147 - TaskScriptRunner - INFO - Training with privacy (ε = 11.61, δ = 1e-05)
# 2025-03-02 23:32:18,530 - TaskScriptRunner - INFO - [1,   800] loss: 2.041
# 2025-03-02 23:32:18,979 - TaskScriptRunner - INFO - Training with privacy (ε = 11.95, δ = 1e-05)
# 2025-03-02 23:32:19,340 - TaskScriptRunner - INFO - [1,   800] loss: 2.034
# 2025-03-02 23:32:19,796 - TaskScriptRunner - INFO - Training with privacy (ε = 11.95, δ = 1e-05)
# 2025-03-02 23:32:24,963 - TaskScriptRunner - INFO - [1,   900] loss: 2.023
# 2025-03-02 23:32:25,492 - TaskScriptRunner - INFO - Training with privacy (ε = 12.26, δ = 1e-05)
# 2025-03-02 23:32:26,094 - TaskScriptRunner - INFO - [1,   900] loss: 2.018
# 2025-03-02 23:32:26,565 - TaskScriptRunner - INFO - Training with privacy (ε = 12.26, δ = 1e-05)
# 2025-03-02 23:32:31,531 - TaskScriptRunner - INFO - [1,  1000] loss: 1.994
# 2025-03-02 23:32:32,076 - TaskScriptRunner - INFO - Training with privacy (ε = 12.56, δ = 1e-05)
# 2025-03-02 23:32:32,532 - TaskScriptRunner - INFO - [1,  1000] loss: 2.007
# 2025-03-02 23:32:33,030 - TaskScriptRunner - INFO - Training with privacy (ε = 12.56, δ = 1e-05)
# 2025-03-02 23:32:37,926 - TaskScriptRunner - INFO - [1,  1100] loss: 2.032
# 2025-03-02 23:32:38,347 - TaskScriptRunner - INFO - Training with privacy (ε = 12.83, δ = 1e-05)
# 2025-03-02 23:32:39,411 - TaskScriptRunner - INFO - [1,  1100] loss: 1.969
# 2025-03-02 23:32:39,819 - TaskScriptRunner - INFO - Training with privacy (ε = 12.83, δ = 1e-05)
# 2025-03-02 23:32:44,580 - TaskScriptRunner - INFO - [1,  1200] loss: 1.960
# 2025-03-02 23:32:45,181 - TaskScriptRunner - INFO - Training with privacy (ε = 13.10, δ = 1e-05)
# 2025-03-02 23:32:45,862 - TaskScriptRunner - INFO - [1,  1200] loss: 1.981
# 2025-03-02 23:32:46,442 - TaskScriptRunner - INFO - Training with privacy (ε = 13.10, δ = 1e-05)
# 2025-03-02 23:32:51,042 - TaskScriptRunner - INFO - [1,  1300] loss: 1.957
# 2025-03-02 23:32:51,672 - TaskScriptRunner - INFO - Training with privacy (ε = 13.35, δ = 1e-05)
# 2025-03-02 23:32:52,509 - TaskScriptRunner - INFO - [1,  1300] loss: 1.956
# 2025-03-02 23:32:53,119 - TaskScriptRunner - INFO - Training with privacy (ε = 13.35, δ = 1e-05)
# 2025-03-02 23:32:57,580 - TaskScriptRunner - INFO - [1,  1400] loss: 1.968
# 2025-03-02 23:32:58,028 - TaskScriptRunner - INFO - Training with privacy (ε = 13.59, δ = 1e-05)
# 2025-03-02 23:32:59,430 - TaskScriptRunner - INFO - [1,  1400] loss: 1.937
# 2025-03-02 23:32:59,837 - TaskScriptRunner - INFO - Training with privacy (ε = 13.59, δ = 1e-05)
# 2025-03-02 23:33:03,879 - TaskScriptRunner - INFO - [1,  1500] loss: 1.960
# 2025-03-02 23:33:04,543 - TaskScriptRunner - INFO - Training with privacy (ε = 13.82, δ = 1e-05)
# 2025-03-02 23:33:05,918 - TaskScriptRunner - INFO - [1,  1500] loss: 1.909
# 2025-03-02 23:33:06,554 - TaskScriptRunner - INFO - Training with privacy (ε = 13.82, δ = 1e-05)
# 2025-03-02 23:33:08,233 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:33:09,699 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:33:09,722 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-02 23:33:10,967 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-02 23:33:11,586 - FedAvg - INFO - aggregating 2 update(s) at round 0
# 2025-03-02 23:33:11,588 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:33:11,591 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:33:11,592 - FedAvg - INFO - Round 1 started.
# 2025-03-02 23:33:11,592 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:33:11,593 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:33:12,003 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:33:12,004 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:33:12,005 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:33:12,006 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:33:12,244 - TaskScriptRunner - INFO - current_round=1, total_rounds=30
# 2025-03-02 23:33:13,504 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:33:13,504 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:33:13,504 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:33:13,511 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:33:13,993 - TaskScriptRunner - INFO - current_round=1, total_rounds=30
# 2025-03-02 23:33:14,140 - TaskScriptRunner - INFO - [1,   100] loss: 1.911
# 2025-03-02 23:33:14,644 - TaskScriptRunner - INFO - Training with privacy (ε = 14.18, δ = 1e-05)
# 2025-03-02 23:33:20,682 - TaskScriptRunner - INFO - [1,   100] loss: 1.903
# 2025-03-02 23:33:20,842 - TaskScriptRunner - INFO - [1,   200] loss: 1.904
# 2025-03-02 23:33:21,205 - TaskScriptRunner - INFO - Training with privacy (ε = 14.18, δ = 1e-05)
# 2025-03-02 23:33:21,527 - TaskScriptRunner - INFO - Training with privacy (ε = 14.39, δ = 1e-05)
# 2025-03-02 23:33:27,464 - TaskScriptRunner - INFO - [1,   200] loss: 1.875
# 2025-03-02 23:33:27,723 - TaskScriptRunner - INFO - [1,   300] loss: 1.889
# 2025-03-02 23:33:28,184 - TaskScriptRunner - INFO - Training with privacy (ε = 14.39, δ = 1e-05)
# 2025-03-02 23:33:28,205 - TaskScriptRunner - INFO - Training with privacy (ε = 14.60, δ = 1e-05)
# 2025-03-02 23:33:34,482 - TaskScriptRunner - INFO - [1,   400] loss: 1.897
# 2025-03-02 23:33:34,607 - TaskScriptRunner - INFO - [1,   300] loss: 1.902
# 2025-03-02 23:33:34,949 - TaskScriptRunner - INFO - Training with privacy (ε = 14.80, δ = 1e-05)
# 2025-03-02 23:33:35,097 - TaskScriptRunner - INFO - Training with privacy (ε = 14.60, δ = 1e-05)
# 2025-03-02 23:33:41,351 - TaskScriptRunner - INFO - [1,   500] loss: 1.897
# 2025-03-02 23:33:41,432 - TaskScriptRunner - INFO - [1,   400] loss: 1.888
# 2025-03-02 23:33:41,892 - TaskScriptRunner - INFO - Training with privacy (ε = 14.80, δ = 1e-05)
# 2025-03-02 23:33:41,896 - TaskScriptRunner - INFO - Training with privacy (ε = 14.99, δ = 1e-05)
# 2025-03-02 23:33:48,356 - TaskScriptRunner - INFO - [1,   500] loss: 1.867
# 2025-03-02 23:33:48,387 - TaskScriptRunner - INFO - [1,   600] loss: 1.855
# 2025-03-02 23:33:48,857 - TaskScriptRunner - INFO - Training with privacy (ε = 15.18, δ = 1e-05)
# 2025-03-02 23:33:48,903 - TaskScriptRunner - INFO - Training with privacy (ε = 14.99, δ = 1e-05)
# 2025-03-02 23:33:55,121 - TaskScriptRunner - INFO - [1,   700] loss: 1.885
# 2025-03-02 23:33:55,158 - TaskScriptRunner - INFO - [1,   600] loss: 1.893
# 2025-03-02 23:33:55,620 - TaskScriptRunner - INFO - Training with privacy (ε = 15.18, δ = 1e-05)
# 2025-03-02 23:33:55,900 - TaskScriptRunner - INFO - Training with privacy (ε = 15.37, δ = 1e-05)
# 2025-03-02 23:34:01,737 - TaskScriptRunner - INFO - [1,   700] loss: 1.897
# 2025-03-02 23:34:01,998 - TaskScriptRunner - INFO - [1,   800] loss: 1.909
# 2025-03-02 23:34:02,531 - TaskScriptRunner - INFO - Training with privacy (ε = 15.37, δ = 1e-05)
# 2025-03-02 23:34:02,830 - TaskScriptRunner - INFO - Training with privacy (ε = 15.55, δ = 1e-05)
# 2025-03-02 23:34:08,730 - TaskScriptRunner - INFO - [1,   800] loss: 1.875
# 2025-03-02 23:34:09,038 - TaskScriptRunner - INFO - [1,   900] loss: 1.854
# 2025-03-02 23:34:09,606 - TaskScriptRunner - INFO - Training with privacy (ε = 15.55, δ = 1e-05)
# 2025-03-02 23:34:09,958 - TaskScriptRunner - INFO - Training with privacy (ε = 15.73, δ = 1e-05)
# 2025-03-02 23:34:15,740 - TaskScriptRunner - INFO - [1,   900] loss: 1.863
# 2025-03-02 23:34:16,149 - TaskScriptRunner - INFO - [1,  1000] loss: 1.889
# 2025-03-02 23:34:16,664 - TaskScriptRunner - INFO - Training with privacy (ε = 15.73, δ = 1e-05)
# 2025-03-02 23:34:17,071 - TaskScriptRunner - INFO - Training with privacy (ε = 15.90, δ = 1e-05)
# 2025-03-02 23:34:22,813 - TaskScriptRunner - INFO - [1,  1000] loss: 1.870
# 2025-03-02 23:34:23,093 - TaskScriptRunner - INFO - [1,  1100] loss: 1.876
# 2025-03-02 23:34:23,747 - TaskScriptRunner - INFO - Training with privacy (ε = 15.90, δ = 1e-05)
# 2025-03-02 23:34:24,004 - TaskScriptRunner - INFO - Training with privacy (ε = 16.07, δ = 1e-05)
# 2025-03-02 23:34:30,097 - TaskScriptRunner - INFO - [1,  1100] loss: 1.895
# 2025-03-02 23:34:30,195 - TaskScriptRunner - INFO - [1,  1200] loss: 1.901
# 2025-03-02 23:34:30,979 - TaskScriptRunner - INFO - Training with privacy (ε = 16.07, δ = 1e-05)
# 2025-03-02 23:34:31,115 - TaskScriptRunner - INFO - Training with privacy (ε = 16.24, δ = 1e-05)
# 2025-03-02 23:34:37,431 - TaskScriptRunner - INFO - [1,  1300] loss: 1.859
# 2025-03-02 23:34:37,462 - TaskScriptRunner - INFO - [1,  1200] loss: 1.845
# 2025-03-02 23:34:37,947 - TaskScriptRunner - INFO - Training with privacy (ε = 16.41, δ = 1e-05)
# 2025-03-02 23:34:38,403 - TaskScriptRunner - INFO - Training with privacy (ε = 16.24, δ = 1e-05)
# 2025-03-02 23:34:43,909 - TaskScriptRunner - INFO - [1,  1400] loss: 1.851
# 2025-03-02 23:34:44,418 - TaskScriptRunner - INFO - [1,  1300] loss: 1.820
# 2025-03-02 23:34:44,518 - TaskScriptRunner - INFO - Training with privacy (ε = 16.57, δ = 1e-05)
# 2025-03-02 23:34:44,938 - TaskScriptRunner - INFO - Training with privacy (ε = 16.41, δ = 1e-05)
# 2025-03-02 23:34:50,869 - TaskScriptRunner - INFO - [1,  1500] loss: 1.854
# 2025-03-02 23:34:51,099 - TaskScriptRunner - INFO - [1,  1400] loss: 1.886
# 2025-03-02 23:34:51,791 - TaskScriptRunner - INFO - Training with privacy (ε = 16.57, δ = 1e-05)
# 2025-03-02 23:34:51,938 - TaskScriptRunner - INFO - Training with privacy (ε = 16.73, δ = 1e-05)
# 2025-03-02 23:34:55,777 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:34:57,072 - TaskScriptRunner - INFO - [1,  1500] loss: 1.863
# 2025-03-02 23:34:57,120 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 31 %
# 2025-03-02 23:34:57,219 - IntimeModelSelector - INFO - validation metric 31 from client site-1
# 2025-03-02 23:34:58,146 - TaskScriptRunner - INFO - Training with privacy (ε = 16.73, δ = 1e-05)
# 2025-03-02 23:34:58,810 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:35:00,090 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 31 %
# 2025-03-02 23:35:00,210 - IntimeModelSelector - INFO - validation metric 31 from client site-2
# 2025-03-02 23:35:00,386 - IntimeModelSelector - INFO - new best validation metric at round 1: 31.0
# 2025-03-02 23:35:00,389 - FedAvg - INFO - aggregating 2 update(s) at round 1
# 2025-03-02 23:35:00,390 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:35:00,393 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:35:00,393 - FedAvg - INFO - Round 2 started.
# 2025-03-02 23:35:00,394 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:35:00,394 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:35:02,318 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:35:02,319 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:35:02,319 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:35:02,321 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:35:02,344 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:35:02,345 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:35:02,345 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:35:02,346 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:35:02,612 - TaskScriptRunner - INFO - current_round=2, total_rounds=30
# 2025-03-02 23:35:02,647 - TaskScriptRunner - INFO - current_round=2, total_rounds=30
# 2025-03-02 23:35:09,513 - TaskScriptRunner - INFO - [1,   100] loss: 1.846
# 2025-03-02 23:35:09,544 - TaskScriptRunner - INFO - [1,   100] loss: 1.862
# 2025-03-02 23:35:10,669 - TaskScriptRunner - INFO - Training with privacy (ε = 16.98, δ = 1e-05)
# 2025-03-02 23:35:10,672 - TaskScriptRunner - INFO - Training with privacy (ε = 16.98, δ = 1e-05)
# 2025-03-02 23:35:16,889 - TaskScriptRunner - INFO - [1,   200] loss: 1.828
# 2025-03-02 23:35:17,111 - TaskScriptRunner - INFO - [1,   200] loss: 1.843
# 2025-03-02 23:35:17,881 - TaskScriptRunner - INFO - Training with privacy (ε = 17.14, δ = 1e-05)
# 2025-03-02 23:35:18,123 - TaskScriptRunner - INFO - Training with privacy (ε = 17.14, δ = 1e-05)
# 2025-03-02 23:35:24,092 - TaskScriptRunner - INFO - [1,   300] loss: 1.846
# 2025-03-02 23:35:24,257 - TaskScriptRunner - INFO - [1,   300] loss: 1.831
# 2025-03-02 23:35:24,661 - TaskScriptRunner - INFO - Training with privacy (ε = 17.29, δ = 1e-05)
# 2025-03-02 23:35:24,875 - TaskScriptRunner - INFO - Training with privacy (ε = 17.29, δ = 1e-05)
# 2025-03-02 23:35:30,886 - TaskScriptRunner - INFO - [1,   400] loss: 1.856
# 2025-03-02 23:35:31,101 - TaskScriptRunner - INFO - [1,   400] loss: 1.836
# 2025-03-02 23:35:31,994 - TaskScriptRunner - INFO - Training with privacy (ε = 17.44, δ = 1e-05)
# 2025-03-02 23:35:32,218 - TaskScriptRunner - INFO - Training with privacy (ε = 17.44, δ = 1e-05)
# 2025-03-02 23:35:38,368 - TaskScriptRunner - INFO - [1,   500] loss: 1.851
# 2025-03-02 23:35:38,488 - TaskScriptRunner - INFO - [1,   500] loss: 1.823
# 2025-03-02 23:35:39,466 - TaskScriptRunner - INFO - Training with privacy (ε = 17.59, δ = 1e-05)
# 2025-03-02 23:35:39,530 - TaskScriptRunner - INFO - Training with privacy (ε = 17.59, δ = 1e-05)
# 2025-03-02 23:35:45,665 - TaskScriptRunner - INFO - [1,   600] loss: 1.832
# 2025-03-02 23:35:45,896 - TaskScriptRunner - INFO - [1,   600] loss: 1.824
# 2025-03-02 23:35:46,230 - TaskScriptRunner - INFO - Training with privacy (ε = 17.73, δ = 1e-05)
# 2025-03-02 23:35:46,541 - TaskScriptRunner - INFO - Training with privacy (ε = 17.73, δ = 1e-05)
# 2025-03-02 23:35:52,459 - TaskScriptRunner - INFO - [1,   700] loss: 1.856
# 2025-03-02 23:35:52,644 - TaskScriptRunner - INFO - [1,   700] loss: 1.838
# 2025-03-02 23:35:53,570 - TaskScriptRunner - INFO - Training with privacy (ε = 17.88, δ = 1e-05)
# 2025-03-02 23:35:53,795 - TaskScriptRunner - INFO - Training with privacy (ε = 17.88, δ = 1e-05)
# 2025-03-02 23:35:59,631 - TaskScriptRunner - INFO - [1,   800] loss: 1.812
# 2025-03-02 23:36:00,029 - TaskScriptRunner - INFO - [1,   800] loss: 1.844
# 2025-03-02 23:36:00,742 - TaskScriptRunner - INFO - Training with privacy (ε = 18.02, δ = 1e-05)
# 2025-03-02 23:36:01,138 - TaskScriptRunner - INFO - Training with privacy (ε = 18.02, δ = 1e-05)
# 2025-03-02 23:36:06,765 - TaskScriptRunner - INFO - [1,   900] loss: 1.841
# 2025-03-02 23:36:07,255 - TaskScriptRunner - INFO - [1,   900] loss: 1.871
# 2025-03-02 23:36:07,575 - TaskScriptRunner - INFO - Training with privacy (ε = 18.16, δ = 1e-05)
# 2025-03-02 23:36:08,082 - TaskScriptRunner - INFO - Training with privacy (ε = 18.16, δ = 1e-05)
# 2025-03-02 23:36:13,721 - TaskScriptRunner - INFO - [1,  1000] loss: 1.836
# 2025-03-02 23:36:14,162 - TaskScriptRunner - INFO - [1,  1000] loss: 1.870
# 2025-03-02 23:36:14,476 - TaskScriptRunner - INFO - Training with privacy (ε = 18.30, δ = 1e-05)
# 2025-03-02 23:36:14,855 - TaskScriptRunner - INFO - Training with privacy (ε = 18.30, δ = 1e-05)
# 2025-03-02 23:36:20,583 - TaskScriptRunner - INFO - [1,  1100] loss: 1.868
# 2025-03-02 23:36:20,922 - TaskScriptRunner - INFO - [1,  1100] loss: 1.836
# 2025-03-02 23:36:21,845 - TaskScriptRunner - INFO - Training with privacy (ε = 18.44, δ = 1e-05)
# 2025-03-02 23:36:22,169 - TaskScriptRunner - INFO - Training with privacy (ε = 18.44, δ = 1e-05)
# 2025-03-02 23:36:27,875 - TaskScriptRunner - INFO - [1,  1200] loss: 1.872
# 2025-03-02 23:36:28,386 - TaskScriptRunner - INFO - [1,  1200] loss: 1.844
# 2025-03-02 23:36:29,102 - TaskScriptRunner - INFO - Training with privacy (ε = 18.57, δ = 1e-05)
# 2025-03-02 23:36:29,669 - TaskScriptRunner - INFO - Training with privacy (ε = 18.57, δ = 1e-05)
# 2025-03-02 23:36:35,058 - TaskScriptRunner - INFO - [1,  1300] loss: 1.865
# 2025-03-02 23:36:35,716 - TaskScriptRunner - INFO - [1,  1300] loss: 1.856
# 2025-03-02 23:36:35,741 - TaskScriptRunner - INFO - Training with privacy (ε = 18.71, δ = 1e-05)
# 2025-03-02 23:36:36,363 - TaskScriptRunner - INFO - Training with privacy (ε = 18.71, δ = 1e-05)
# 2025-03-02 23:36:41,644 - TaskScriptRunner - INFO - [1,  1400] loss: 1.841
# 2025-03-02 23:36:42,226 - TaskScriptRunner - INFO - [1,  1400] loss: 1.854
# 2025-03-02 23:36:42,928 - TaskScriptRunner - INFO - Training with privacy (ε = 18.84, δ = 1e-05)
# 2025-03-02 23:36:43,507 - TaskScriptRunner - INFO - Training with privacy (ε = 18.84, δ = 1e-05)
# 2025-03-02 23:36:48,930 - TaskScriptRunner - INFO - [1,  1500] loss: 1.822
# 2025-03-02 23:36:49,482 - TaskScriptRunner - INFO - [1,  1500] loss: 1.782
# 2025-03-02 23:36:50,241 - TaskScriptRunner - INFO - Training with privacy (ε = 18.97, δ = 1e-05)
# 2025-03-02 23:36:50,778 - TaskScriptRunner - INFO - Training with privacy (ε = 18.97, δ = 1e-05)
# 2025-03-02 23:36:53,839 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:36:54,279 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:36:55,094 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 37 %
# 2025-03-02 23:36:55,488 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 37 %
# 2025-03-02 23:36:55,523 - IntimeModelSelector - INFO - validation metric 37 from client site-2
# 2025-03-02 23:36:55,651 - IntimeModelSelector - INFO - validation metric 37 from client site-1
# 2025-03-02 23:36:55,838 - IntimeModelSelector - INFO - new best validation metric at round 2: 37.0
# 2025-03-02 23:36:55,841 - FedAvg - INFO - aggregating 2 update(s) at round 2
# 2025-03-02 23:36:55,842 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:36:55,845 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:36:55,845 - FedAvg - INFO - Round 3 started.
# 2025-03-02 23:36:55,846 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:36:55,846 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:36:57,658 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:36:57,659 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:36:57,659 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:36:57,660 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:36:57,802 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:36:57,803 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:36:57,803 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:36:57,805 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:36:58,010 - TaskScriptRunner - INFO - current_round=3, total_rounds=30
# 2025-03-02 23:36:58,116 - TaskScriptRunner - INFO - current_round=3, total_rounds=30
# 2025-03-02 23:37:04,753 - TaskScriptRunner - INFO - [1,   100] loss: 1.793
# 2025-03-02 23:37:04,792 - TaskScriptRunner - INFO - [1,   100] loss: 1.833
# 2025-03-02 23:37:06,146 - TaskScriptRunner - INFO - Training with privacy (ε = 19.19, δ = 1e-05)
# 2025-03-02 23:37:06,166 - TaskScriptRunner - INFO - Training with privacy (ε = 19.19, δ = 1e-05)
# 2025-03-02 23:37:12,406 - TaskScriptRunner - INFO - [1,   200] loss: 1.826
# 2025-03-02 23:37:12,602 - TaskScriptRunner - INFO - [1,   200] loss: 1.822
# 2025-03-02 23:37:13,295 - TaskScriptRunner - INFO - Training with privacy (ε = 19.31, δ = 1e-05)
# 2025-03-02 23:37:13,480 - TaskScriptRunner - INFO - Training with privacy (ε = 19.31, δ = 1e-05)
# 2025-03-02 23:37:19,248 - TaskScriptRunner - INFO - [1,   300] loss: 1.825
# 2025-03-02 23:37:19,669 - TaskScriptRunner - INFO - [1,   300] loss: 1.884
# 2025-03-02 23:37:19,976 - TaskScriptRunner - INFO - Training with privacy (ε = 19.44, δ = 1e-05)
# 2025-03-02 23:37:20,403 - TaskScriptRunner - INFO - Training with privacy (ε = 19.44, δ = 1e-05)
# 2025-03-02 23:37:26,127 - TaskScriptRunner - INFO - [1,   400] loss: 1.839
# 2025-03-02 23:37:26,394 - TaskScriptRunner - INFO - [1,   400] loss: 1.814
# 2025-03-02 23:37:27,432 - TaskScriptRunner - INFO - Training with privacy (ε = 19.57, δ = 1e-05)
# 2025-03-02 23:37:27,725 - TaskScriptRunner - INFO - Training with privacy (ε = 19.57, δ = 1e-05)
# 2025-03-02 23:37:33,571 - TaskScriptRunner - INFO - [1,   500] loss: 1.830
# 2025-03-02 23:37:33,953 - TaskScriptRunner - INFO - [1,   500] loss: 1.879
# 2025-03-02 23:37:34,972 - TaskScriptRunner - INFO - Training with privacy (ε = 19.69, δ = 1e-05)
# 2025-03-02 23:37:35,315 - TaskScriptRunner - INFO - Training with privacy (ε = 19.69, δ = 1e-05)
# 2025-03-02 23:37:41,155 - TaskScriptRunner - INFO - [1,   600] loss: 1.842
# 2025-03-02 23:37:41,438 - TaskScriptRunner - INFO - [1,   600] loss: 1.855
# 2025-03-02 23:37:42,507 - TaskScriptRunner - INFO - Training with privacy (ε = 19.82, δ = 1e-05)
# 2025-03-02 23:37:42,793 - TaskScriptRunner - INFO - Training with privacy (ε = 19.82, δ = 1e-05)
# 2025-03-02 23:37:48,578 - TaskScriptRunner - INFO - [1,   700] loss: 1.858
# 2025-03-02 23:37:49,032 - TaskScriptRunner - INFO - [1,   700] loss: 1.859
# 2025-03-02 23:37:49,426 - TaskScriptRunner - INFO - Training with privacy (ε = 19.94, δ = 1e-05)
# 2025-03-02 23:37:49,796 - TaskScriptRunner - INFO - Training with privacy (ε = 19.94, δ = 1e-05)
# 2025-03-02 23:37:55,630 - TaskScriptRunner - INFO - [1,   800] loss: 1.799
# 2025-03-02 23:37:55,935 - TaskScriptRunner - INFO - [1,   800] loss: 1.827
# 2025-03-02 23:37:56,787 - TaskScriptRunner - INFO - Training with privacy (ε = 20.06, δ = 1e-05)
# 2025-03-02 23:37:56,991 - TaskScriptRunner - INFO - Training with privacy (ε = 20.06, δ = 1e-05)
# 2025-03-02 23:38:02,992 - TaskScriptRunner - INFO - [1,   900] loss: 1.832
# 2025-03-02 23:38:03,178 - TaskScriptRunner - INFO - [1,   900] loss: 1.834
# 2025-03-02 23:38:04,440 - TaskScriptRunner - INFO - Training with privacy (ε = 20.19, δ = 1e-05)
# 2025-03-02 23:38:04,641 - TaskScriptRunner - INFO - Training with privacy (ε = 20.19, δ = 1e-05)
# 2025-03-02 23:38:10,748 - TaskScriptRunner - INFO - [1,  1000] loss: 1.856
# 2025-03-02 23:38:10,889 - TaskScriptRunner - INFO - [1,  1000] loss: 1.803
# 2025-03-02 23:38:12,226 - TaskScriptRunner - INFO - Training with privacy (ε = 20.31, δ = 1e-05)
# 2025-03-02 23:38:12,329 - TaskScriptRunner - INFO - Training with privacy (ε = 20.31, δ = 1e-05)
# 2025-03-02 23:38:18,670 - TaskScriptRunner - INFO - [1,  1100] loss: 1.896
# 2025-03-02 23:38:18,700 - TaskScriptRunner - INFO - [1,  1100] loss: 1.830
# 2025-03-02 23:38:20,131 - TaskScriptRunner - INFO - Training with privacy (ε = 20.43, δ = 1e-05)
# 2025-03-02 23:38:20,173 - TaskScriptRunner - INFO - Training with privacy (ε = 20.43, δ = 1e-05)
# 2025-03-02 23:38:26,498 - TaskScriptRunner - INFO - [1,  1200] loss: 1.838
# 2025-03-02 23:38:26,608 - TaskScriptRunner - INFO - [1,  1200] loss: 1.822
# 2025-03-02 23:38:27,663 - TaskScriptRunner - INFO - Training with privacy (ε = 20.54, δ = 1e-05)
# 2025-03-02 23:38:27,728 - TaskScriptRunner - INFO - Training with privacy (ε = 20.54, δ = 1e-05)
# 2025-03-02 23:38:33,988 - TaskScriptRunner - INFO - [1,  1300] loss: 1.859
# 2025-03-02 23:38:34,055 - TaskScriptRunner - INFO - [1,  1300] loss: 1.838
# 2025-03-02 23:38:35,449 - TaskScriptRunner - INFO - Training with privacy (ε = 20.66, δ = 1e-05)
# 2025-03-02 23:38:35,528 - TaskScriptRunner - INFO - Training with privacy (ε = 20.66, δ = 1e-05)
# 2025-03-02 23:38:41,834 - TaskScriptRunner - INFO - [1,  1400] loss: 1.832
# 2025-03-02 23:38:41,865 - TaskScriptRunner - INFO - [1,  1400] loss: 1.819
# 2025-03-02 23:38:42,819 - TaskScriptRunner - INFO - Training with privacy (ε = 20.78, δ = 1e-05)
# 2025-03-02 23:38:42,847 - TaskScriptRunner - INFO - Training with privacy (ε = 20.78, δ = 1e-05)
# 2025-03-02 23:38:49,072 - TaskScriptRunner - INFO - [1,  1500] loss: 1.841
# 2025-03-02 23:38:49,127 - TaskScriptRunner - INFO - [1,  1500] loss: 1.873
# 2025-03-02 23:38:50,571 - TaskScriptRunner - INFO - Training with privacy (ε = 20.89, δ = 1e-05)
# 2025-03-02 23:38:50,627 - TaskScriptRunner - INFO - Training with privacy (ε = 20.89, δ = 1e-05)
# 2025-03-02 23:38:54,532 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:38:54,549 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:38:55,714 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 40 %
# 2025-03-02 23:38:55,758 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 40 %
# 2025-03-02 23:38:55,844 - IntimeModelSelector - INFO - validation metric 40 from client site-2
# 2025-03-02 23:38:56,024 - IntimeModelSelector - INFO - validation metric 40 from client site-1
# 2025-03-02 23:38:56,217 - IntimeModelSelector - INFO - new best validation metric at round 3: 40.0
# 2025-03-02 23:38:56,220 - FedAvg - INFO - aggregating 2 update(s) at round 3
# 2025-03-02 23:38:56,221 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:38:56,224 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:38:56,224 - FedAvg - INFO - Round 4 started.
# 2025-03-02 23:38:56,225 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:38:56,225 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:38:57,953 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:38:57,954 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:38:57,954 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:38:57,955 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:38:58,124 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:38:58,125 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:38:58,125 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:38:58,126 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:38:58,231 - TaskScriptRunner - INFO - current_round=4, total_rounds=30
# 2025-03-02 23:38:58,274 - TaskScriptRunner - INFO - current_round=4, total_rounds=30
# 2025-03-02 23:39:04,780 - TaskScriptRunner - INFO - [1,   100] loss: 1.799
# 2025-03-02 23:39:04,987 - TaskScriptRunner - INFO - [1,   100] loss: 1.813
# 2025-03-02 23:39:06,582 - TaskScriptRunner - INFO - Training with privacy (ε = 21.08, δ = 1e-05)
# 2025-03-02 23:39:06,875 - TaskScriptRunner - INFO - Training with privacy (ε = 21.08, δ = 1e-05)
# 2025-03-02 23:39:12,675 - TaskScriptRunner - INFO - [1,   200] loss: 1.833
# 2025-03-02 23:39:13,031 - TaskScriptRunner - INFO - [1,   200] loss: 1.835
# 2025-03-02 23:39:14,211 - TaskScriptRunner - INFO - Training with privacy (ε = 21.20, δ = 1e-05)
# 2025-03-02 23:39:14,581 - TaskScriptRunner - INFO - Training with privacy (ε = 21.20, δ = 1e-05)
# 2025-03-02 23:39:20,537 - TaskScriptRunner - INFO - [1,   300] loss: 1.827
# 2025-03-02 23:39:20,709 - TaskScriptRunner - INFO - [1,   300] loss: 1.810
# 2025-03-02 23:39:22,048 - TaskScriptRunner - INFO - Training with privacy (ε = 21.31, δ = 1e-05)
# 2025-03-02 23:39:22,226 - TaskScriptRunner - INFO - Training with privacy (ε = 21.31, δ = 1e-05)
# 2025-03-02 23:39:28,069 - TaskScriptRunner - INFO - [1,   400] loss: 1.801
# 2025-03-02 23:39:28,398 - TaskScriptRunner - INFO - [1,   400] loss: 1.837
# 2025-03-02 23:39:29,649 - TaskScriptRunner - INFO - Training with privacy (ε = 21.42, δ = 1e-05)
# 2025-03-02 23:39:30,008 - TaskScriptRunner - INFO - Training with privacy (ε = 21.42, δ = 1e-05)
# 2025-03-02 23:39:35,744 - TaskScriptRunner - INFO - [1,   500] loss: 1.806
# 2025-03-02 23:39:36,053 - TaskScriptRunner - INFO - [1,   500] loss: 1.809
# 2025-03-02 23:39:37,003 - TaskScriptRunner - INFO - Training with privacy (ε = 21.53, δ = 1e-05)
# 2025-03-02 23:39:37,314 - TaskScriptRunner - INFO - Training with privacy (ε = 21.53, δ = 1e-05)
# 2025-03-02 23:39:43,100 - TaskScriptRunner - INFO - [1,   600] loss: 1.864
# 2025-03-02 23:39:43,495 - TaskScriptRunner - INFO - [1,   600] loss: 1.796
# 2025-03-02 23:39:44,847 - TaskScriptRunner - INFO - Training with privacy (ε = 21.65, δ = 1e-05)
# 2025-03-02 23:39:45,129 - TaskScriptRunner - INFO - Training with privacy (ε = 21.65, δ = 1e-05)
# 2025-03-02 23:39:51,115 - TaskScriptRunner - INFO - [1,   700] loss: 1.802
# 2025-03-02 23:39:51,254 - TaskScriptRunner - INFO - [1,   700] loss: 1.859
# 2025-03-02 23:39:52,758 - TaskScriptRunner - INFO - Training with privacy (ε = 21.76, δ = 1e-05)
# 2025-03-02 23:39:52,845 - TaskScriptRunner - INFO - Training with privacy (ε = 21.76, δ = 1e-05)
# 2025-03-02 23:39:59,057 - TaskScriptRunner - INFO - [1,   800] loss: 1.860
# 2025-03-02 23:39:59,171 - TaskScriptRunner - INFO - [1,   800] loss: 1.839
# 2025-03-02 23:40:00,771 - TaskScriptRunner - INFO - Training with privacy (ε = 21.87, δ = 1e-05)
# 2025-03-02 23:40:00,861 - TaskScriptRunner - INFO - Training with privacy (ε = 21.87, δ = 1e-05)
# 2025-03-02 23:40:06,938 - TaskScriptRunner - INFO - [1,   900] loss: 1.842
# 2025-03-02 23:40:07,044 - TaskScriptRunner - INFO - [1,   900] loss: 1.814
# 2025-03-02 23:40:08,733 - TaskScriptRunner - INFO - Training with privacy (ε = 21.97, δ = 1e-05)
# 2025-03-02 23:40:08,952 - TaskScriptRunner - INFO - Training with privacy (ε = 21.97, δ = 1e-05)
# 2025-03-02 23:40:14,998 - TaskScriptRunner - INFO - [1,  1000] loss: 1.875
# 2025-03-02 23:40:15,260 - TaskScriptRunner - INFO - [1,  1000] loss: 1.868
# 2025-03-02 23:40:15,875 - TaskScriptRunner - INFO - Training with privacy (ε = 22.08, δ = 1e-05)
# 2025-03-02 23:40:16,165 - TaskScriptRunner - INFO - Training with privacy (ε = 22.08, δ = 1e-05)
# 2025-03-02 23:40:21,790 - TaskScriptRunner - INFO - [1,  1100] loss: 1.831
# 2025-03-02 23:40:22,255 - TaskScriptRunner - INFO - [1,  1100] loss: 1.822
# 2025-03-02 23:40:23,091 - TaskScriptRunner - INFO - Training with privacy (ε = 22.19, δ = 1e-05)
# 2025-03-02 23:40:23,533 - TaskScriptRunner - INFO - Training with privacy (ε = 22.19, δ = 1e-05)
# 2025-03-02 23:40:28,947 - TaskScriptRunner - INFO - [1,  1200] loss: 1.828
# 2025-03-02 23:40:29,610 - TaskScriptRunner - INFO - [1,  1200] loss: 1.840
# 2025-03-02 23:40:29,986 - TaskScriptRunner - INFO - Training with privacy (ε = 22.30, δ = 1e-05)
# 2025-03-02 23:40:30,604 - TaskScriptRunner - INFO - Training with privacy (ε = 22.30, δ = 1e-05)
# 2025-03-02 23:40:36,061 - TaskScriptRunner - INFO - [1,  1300] loss: 1.866
# 2025-03-02 23:40:36,650 - TaskScriptRunner - INFO - [1,  1300] loss: 1.900
# 2025-03-02 23:40:37,797 - TaskScriptRunner - INFO - Training with privacy (ε = 22.41, δ = 1e-05)
# 2025-03-02 23:40:38,370 - TaskScriptRunner - INFO - Training with privacy (ε = 22.41, δ = 1e-05)
# 2025-03-02 23:40:43,845 - TaskScriptRunner - INFO - [1,  1400] loss: 1.819
# 2025-03-02 23:40:44,422 - TaskScriptRunner - INFO - [1,  1400] loss: 1.843
# 2025-03-02 23:40:45,251 - TaskScriptRunner - INFO - Training with privacy (ε = 22.51, δ = 1e-05)
# 2025-03-02 23:40:45,802 - TaskScriptRunner - INFO - Training with privacy (ε = 22.51, δ = 1e-05)
# 2025-03-02 23:40:51,346 - TaskScriptRunner - INFO - [1,  1500] loss: 1.803
# 2025-03-02 23:40:51,734 - TaskScriptRunner - INFO - [1,  1500] loss: 1.854
# 2025-03-02 23:40:52,352 - TaskScriptRunner - INFO - Training with privacy (ε = 22.62, δ = 1e-05)
# 2025-03-02 23:40:52,794 - TaskScriptRunner - INFO - Training with privacy (ε = 22.62, δ = 1e-05)
# 2025-03-02 23:40:56,006 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:40:56,478 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:40:57,264 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 43 %
# 2025-03-02 23:40:57,663 - IntimeModelSelector - INFO - validation metric 43 from client site-2
# 2025-03-02 23:40:57,750 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 43 %
# 2025-03-02 23:40:57,808 - IntimeModelSelector - INFO - validation metric 43 from client site-1
# 2025-03-02 23:40:58,121 - IntimeModelSelector - INFO - new best validation metric at round 4: 43.0
# 2025-03-02 23:40:58,125 - FedAvg - INFO - aggregating 2 update(s) at round 4
# 2025-03-02 23:40:58,126 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:40:58,129 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:40:58,129 - FedAvg - INFO - Round 5 started.
# 2025-03-02 23:40:58,130 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:40:58,130 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:40:59,794 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:40:59,795 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:40:59,796 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:40:59,797 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:40:59,939 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:40:59,939 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:40:59,940 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:40:59,941 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:41:00,273 - TaskScriptRunner - INFO - current_round=5, total_rounds=30
# 2025-03-02 23:41:00,291 - TaskScriptRunner - INFO - current_round=5, total_rounds=30
# 2025-03-02 23:41:06,914 - TaskScriptRunner - INFO - [1,   100] loss: 1.847
# 2025-03-02 23:41:07,141 - TaskScriptRunner - INFO - [1,   100] loss: 1.770
# 2025-03-02 23:41:08,865 - TaskScriptRunner - INFO - Training with privacy (ε = 22.79, δ = 1e-05)
# 2025-03-02 23:41:09,062 - TaskScriptRunner - INFO - Training with privacy (ε = 22.79, δ = 1e-05)
# 2025-03-02 23:41:15,110 - TaskScriptRunner - INFO - [1,   200] loss: 1.781
# 2025-03-02 23:41:15,330 - TaskScriptRunner - INFO - [1,   200] loss: 1.879
# 2025-03-02 23:41:16,992 - TaskScriptRunner - INFO - Training with privacy (ε = 22.89, δ = 1e-05)
# 2025-03-02 23:41:17,223 - TaskScriptRunner - INFO - Training with privacy (ε = 22.89, δ = 1e-05)
# 2025-03-02 23:41:23,207 - TaskScriptRunner - INFO - [1,   300] loss: 1.841
# 2025-03-02 23:41:23,513 - TaskScriptRunner - INFO - [1,   300] loss: 1.841
# 2025-03-02 23:41:25,028 - TaskScriptRunner - INFO - Training with privacy (ε = 23.00, δ = 1e-05)
# 2025-03-02 23:41:25,318 - TaskScriptRunner - INFO - Training with privacy (ε = 23.00, δ = 1e-05)
# 2025-03-02 23:41:31,391 - TaskScriptRunner - INFO - [1,   400] loss: 1.876
# 2025-03-02 23:41:31,565 - TaskScriptRunner - INFO - [1,   400] loss: 1.816
# 2025-03-02 23:41:33,369 - TaskScriptRunner - INFO - Training with privacy (ε = 23.10, δ = 1e-05)
# 2025-03-02 23:41:33,549 - TaskScriptRunner - INFO - Training with privacy (ε = 23.10, δ = 1e-05)
# 2025-03-02 23:41:39,798 - TaskScriptRunner - INFO - [1,   500] loss: 1.855
# 2025-03-02 23:41:39,854 - TaskScriptRunner - INFO - [1,   500] loss: 1.861
# 2025-03-02 23:41:41,770 - TaskScriptRunner - INFO - Training with privacy (ε = 23.20, δ = 1e-05)
# 2025-03-02 23:41:41,841 - TaskScriptRunner - INFO - Training with privacy (ε = 23.20, δ = 1e-05)
# 2025-03-02 23:41:47,956 - TaskScriptRunner - INFO - [1,   600] loss: 1.794
# 2025-03-02 23:41:48,240 - TaskScriptRunner - INFO - [1,   600] loss: 1.806
# 2025-03-02 23:41:49,922 - TaskScriptRunner - INFO - Training with privacy (ε = 23.30, δ = 1e-05)
# 2025-03-02 23:41:50,136 - TaskScriptRunner - INFO - Training with privacy (ε = 23.30, δ = 1e-05)
# 2025-03-02 23:41:56,067 - TaskScriptRunner - INFO - [1,   700] loss: 1.883
# 2025-03-02 23:41:56,328 - TaskScriptRunner - INFO - [1,   700] loss: 1.862
# 2025-03-02 23:41:57,254 - TaskScriptRunner - INFO - Training with privacy (ε = 23.40, δ = 1e-05)
# 2025-03-02 23:41:57,522 - TaskScriptRunner - INFO - Training with privacy (ε = 23.40, δ = 1e-05)
# 2025-03-02 23:42:03,558 - TaskScriptRunner - INFO - [1,   800] loss: 1.823
# 2025-03-02 23:42:03,759 - TaskScriptRunner - INFO - [1,   800] loss: 1.838
# 2025-03-02 23:42:04,821 - TaskScriptRunner - INFO - Training with privacy (ε = 23.51, δ = 1e-05)
# 2025-03-02 23:42:05,015 - TaskScriptRunner - INFO - Training with privacy (ε = 23.51, δ = 1e-05)
# 2025-03-02 23:42:11,149 - TaskScriptRunner - INFO - [1,   900] loss: 1.876
# 2025-03-02 23:42:11,253 - TaskScriptRunner - INFO - [1,   900] loss: 1.871
# 2025-03-02 23:42:13,126 - TaskScriptRunner - INFO - Training with privacy (ε = 23.61, δ = 1e-05)
# 2025-03-02 23:42:13,211 - TaskScriptRunner - INFO - Training with privacy (ε = 23.61, δ = 1e-05)
# 2025-03-02 23:42:19,558 - TaskScriptRunner - INFO - [1,  1000] loss: 1.820
# 2025-03-02 23:42:19,611 - TaskScriptRunner - INFO - [1,  1000] loss: 1.851
# 2025-03-02 23:42:21,648 - TaskScriptRunner - INFO - Training with privacy (ε = 23.71, δ = 1e-05)
# 2025-03-02 23:42:21,706 - TaskScriptRunner - INFO - Training with privacy (ε = 23.71, δ = 1e-05)
# 2025-03-02 23:42:27,956 - TaskScriptRunner - INFO - [1,  1100] loss: 1.865
# 2025-03-02 23:42:27,987 - TaskScriptRunner - INFO - [1,  1100] loss: 1.830
# 2025-03-02 23:42:29,877 - TaskScriptRunner - INFO - Training with privacy (ε = 23.81, δ = 1e-05)
# 2025-03-02 23:42:29,938 - TaskScriptRunner - INFO - Training with privacy (ε = 23.81, δ = 1e-05)
# 2025-03-02 23:42:36,220 - TaskScriptRunner - INFO - [1,  1200] loss: 1.828
# 2025-03-02 23:42:36,259 - TaskScriptRunner - INFO - [1,  1200] loss: 1.819
# 2025-03-02 23:42:38,204 - TaskScriptRunner - INFO - Training with privacy (ε = 23.90, δ = 1e-05)
# 2025-03-02 23:42:38,280 - TaskScriptRunner - INFO - Training with privacy (ε = 23.90, δ = 1e-05)
# 2025-03-02 23:42:44,541 - TaskScriptRunner - INFO - [1,  1300] loss: 1.795
# 2025-03-02 23:42:44,652 - TaskScriptRunner - INFO - [1,  1300] loss: 1.850
# 2025-03-02 23:42:46,714 - TaskScriptRunner - INFO - Training with privacy (ε = 24.00, δ = 1e-05)
# 2025-03-02 23:42:46,781 - TaskScriptRunner - INFO - Training with privacy (ε = 24.00, δ = 1e-05)
# 2025-03-02 23:42:52,996 - TaskScriptRunner - INFO - [1,  1400] loss: 1.822
# 2025-03-02 23:42:53,113 - TaskScriptRunner - INFO - [1,  1400] loss: 1.869
# 2025-03-02 23:42:54,963 - TaskScriptRunner - INFO - Training with privacy (ε = 24.10, δ = 1e-05)
# 2025-03-02 23:42:55,122 - TaskScriptRunner - INFO - Training with privacy (ε = 24.10, δ = 1e-05)
# 2025-03-02 23:43:01,336 - TaskScriptRunner - INFO - [1,  1500] loss: 1.832
# 2025-03-02 23:43:01,424 - TaskScriptRunner - INFO - [1,  1500] loss: 1.817
# 2025-03-02 23:43:03,301 - TaskScriptRunner - INFO - Training with privacy (ε = 24.20, δ = 1e-05)
# 2025-03-02 23:43:03,438 - TaskScriptRunner - INFO - Training with privacy (ε = 24.20, δ = 1e-05)
# 2025-03-02 23:43:07,206 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:43:07,213 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:43:08,543 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 44 %
# 2025-03-02 23:43:08,568 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 44 %
# 2025-03-02 23:43:08,702 - IntimeModelSelector - INFO - validation metric 44 from client site-1
# 2025-03-02 23:43:08,996 - IntimeModelSelector - INFO - validation metric 44 from client site-2
# 2025-03-02 23:43:09,291 - IntimeModelSelector - INFO - new best validation metric at round 5: 44.0
# 2025-03-02 23:43:09,295 - FedAvg - INFO - aggregating 2 update(s) at round 5
# 2025-03-02 23:43:09,296 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:43:09,299 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:43:09,299 - FedAvg - INFO - Round 6 started.
# 2025-03-02 23:43:09,299 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:43:09,300 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:43:10,816 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:43:10,816 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:43:10,817 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:43:10,818 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:43:11,092 - TaskScriptRunner - INFO - current_round=6, total_rounds=30
# 2025-03-02 23:43:11,116 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:43:11,116 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:43:11,117 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:43:11,117 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:43:11,565 - TaskScriptRunner - INFO - current_round=6, total_rounds=30
# 2025-03-02 23:43:17,522 - TaskScriptRunner - INFO - [1,   100] loss: 1.823
# 2025-03-02 23:43:18,037 - TaskScriptRunner - INFO - [1,   100] loss: 1.745
# 2025-03-02 23:43:19,517 - TaskScriptRunner - INFO - Training with privacy (ε = 24.36, δ = 1e-05)
# 2025-03-02 23:43:20,000 - TaskScriptRunner - INFO - Training with privacy (ε = 24.36, δ = 1e-05)
# 2025-03-02 23:43:25,431 - TaskScriptRunner - INFO - [1,   200] loss: 1.832
# 2025-03-02 23:43:26,052 - TaskScriptRunner - INFO - [1,   200] loss: 1.828
# 2025-03-02 23:43:27,428 - TaskScriptRunner - INFO - Training with privacy (ε = 24.46, δ = 1e-05)
# 2025-03-02 23:43:28,023 - TaskScriptRunner - INFO - Training with privacy (ε = 24.46, δ = 1e-05)
# 2025-03-02 23:43:33,483 - TaskScriptRunner - INFO - [1,   300] loss: 1.780
# 2025-03-02 23:43:33,981 - TaskScriptRunner - INFO - [1,   300] loss: 1.867
# 2025-03-02 23:43:36,313 - TaskScriptRunner - INFO - Training with privacy (ε = 24.55, δ = 1e-05)
# 2025-03-02 23:43:36,874 - TaskScriptRunner - INFO - Training with privacy (ε = 24.55, δ = 1e-05)
# 2025-03-02 23:43:42,419 - TaskScriptRunner - INFO - [1,   400] loss: 1.871
# 2025-03-02 23:43:42,842 - TaskScriptRunner - INFO - [1,   400] loss: 1.810
# 2025-03-02 23:43:43,814 - TaskScriptRunner - INFO - Training with privacy (ε = 24.65, δ = 1e-05)
# 2025-03-02 23:43:44,211 - TaskScriptRunner - INFO - Training with privacy (ε = 24.65, δ = 1e-05)
# 2025-03-02 23:43:49,862 - TaskScriptRunner - INFO - [1,   500] loss: 1.788
# 2025-03-02 23:43:50,210 - TaskScriptRunner - INFO - [1,   500] loss: 1.751
# 2025-03-02 23:43:52,177 - TaskScriptRunner - INFO - Training with privacy (ε = 24.74, δ = 1e-05)
# 2025-03-02 23:43:52,453 - TaskScriptRunner - INFO - Training with privacy (ε = 24.74, δ = 1e-05)
# 2025-03-02 23:43:58,434 - TaskScriptRunner - INFO - [1,   600] loss: 1.805
# 2025-03-02 23:43:58,598 - TaskScriptRunner - INFO - [1,   600] loss: 1.771
# 2025-03-02 23:44:00,662 - TaskScriptRunner - INFO - Training with privacy (ε = 24.84, δ = 1e-05)
# 2025-03-02 23:44:00,789 - TaskScriptRunner - INFO - Training with privacy (ε = 24.84, δ = 1e-05)
# 2025-03-02 23:44:06,962 - TaskScriptRunner - INFO - [1,   700] loss: 1.770
# 2025-03-02 23:44:07,121 - TaskScriptRunner - INFO - [1,   700] loss: 1.869
# 2025-03-02 23:44:09,036 - TaskScriptRunner - INFO - Training with privacy (ε = 24.93, δ = 1e-05)
# 2025-03-02 23:44:09,180 - TaskScriptRunner - INFO - Training with privacy (ε = 24.93, δ = 1e-05)
# 2025-03-02 23:44:15,432 - TaskScriptRunner - INFO - [1,   800] loss: 1.836
# 2025-03-02 23:44:15,472 - TaskScriptRunner - INFO - [1,   800] loss: 1.808
# 2025-03-02 23:44:17,792 - TaskScriptRunner - INFO - Training with privacy (ε = 25.03, δ = 1e-05)
# 2025-03-02 23:44:17,795 - TaskScriptRunner - INFO - Training with privacy (ε = 25.03, δ = 1e-05)
# 2025-03-02 23:44:24,106 - TaskScriptRunner - INFO - [1,   900] loss: 1.829
# 2025-03-02 23:44:24,153 - TaskScriptRunner - INFO - [1,   900] loss: 1.893
# ...
# 2025-03-02 23:52:29,229 - TaskScriptRunner - INFO - Training with privacy (ε = 30.30, δ = 1e-05)
# 2025-03-02 23:52:30,395 - TaskScriptRunner - INFO - [1,   700] loss: 1.835
# 2025-03-02 23:52:32,390 - TaskScriptRunner - INFO - Training with privacy (ε = 30.30, δ = 1e-05)
# 2025-03-02 23:52:34,344 - TaskScriptRunner - INFO - [1,   800] loss: 1.852
# 2025-03-02 23:52:36,939 - TaskScriptRunner - INFO - [1,   800] loss: 1.787
# 2025-03-02 23:52:37,494 - TaskScriptRunner - INFO - Training with privacy (ε = 30.38, δ = 1e-05)
# 2025-03-02 23:52:39,990 - TaskScriptRunner - INFO - Training with privacy (ε = 30.38, δ = 1e-05)
# 2025-03-02 23:52:42,130 - TaskScriptRunner - INFO - [1,   900] loss: 1.835
# 2025-03-02 23:52:44,606 - TaskScriptRunner - INFO - [1,   900] loss: 1.799
# 2025-03-02 23:52:45,410 - TaskScriptRunner - INFO - Training with privacy (ε = 30.46, δ = 1e-05)
# 2025-03-02 23:52:47,713 - TaskScriptRunner - INFO - Training with privacy (ε = 30.46, δ = 1e-05)
# 2025-03-02 23:52:50,178 - TaskScriptRunner - INFO - [1,  1000] loss: 1.861
# 2025-03-02 23:52:52,443 - TaskScriptRunner - INFO - [1,  1000] loss: 1.774
# 2025-03-02 23:52:53,422 - TaskScriptRunner - INFO - Training with privacy (ε = 30.54, δ = 1e-05)
# 2025-03-02 23:52:55,623 - TaskScriptRunner - INFO - Training with privacy (ε = 30.54, δ = 1e-05)
# 2025-03-02 23:52:58,360 - TaskScriptRunner - INFO - [1,  1100] loss: 1.769
# 2025-03-02 23:53:00,448 - TaskScriptRunner - INFO - [1,  1100] loss: 1.760
# 2025-03-02 23:53:01,639 - TaskScriptRunner - INFO - Training with privacy (ε = 30.61, δ = 1e-05)
# 2025-03-02 23:53:03,645 - TaskScriptRunner - INFO - Training with privacy (ε = 30.61, δ = 1e-05)
# 2025-03-02 23:53:06,641 - TaskScriptRunner - INFO - [1,  1200] loss: 1.830
# 2025-03-02 23:53:08,278 - TaskScriptRunner - INFO - Training with privacy (ε = 30.69, δ = 1e-05)
# 2025-03-02 23:53:08,889 - TaskScriptRunner - INFO - [1,  1200] loss: 1.839
# 2025-03-02 23:53:10,568 - TaskScriptRunner - INFO - Training with privacy (ε = 30.69, δ = 1e-05)
# 2025-03-02 23:53:13,449 - TaskScriptRunner - INFO - [1,  1300] loss: 1.825
# 2025-03-02 23:53:15,497 - TaskScriptRunner - INFO - [1,  1300] loss: 1.753
# 2025-03-02 23:53:16,806 - TaskScriptRunner - INFO - Training with privacy (ε = 30.77, δ = 1e-05)
# 2025-03-02 23:53:18,734 - TaskScriptRunner - INFO - Training with privacy (ε = 30.77, δ = 1e-05)
# 2025-03-02 23:53:21,657 - TaskScriptRunner - INFO - [1,  1400] loss: 1.843
# 2025-03-02 23:53:23,795 - TaskScriptRunner - INFO - [1,  1400] loss: 1.777
# 2025-03-02 23:53:25,066 - TaskScriptRunner - INFO - Training with privacy (ε = 30.85, δ = 1e-05)
# 2025-03-02 23:53:27,079 - TaskScriptRunner - INFO - Training with privacy (ε = 30.85, δ = 1e-05)
# 2025-03-02 23:53:30,001 - TaskScriptRunner - INFO - [1,  1500] loss: 1.783
# 2025-03-02 23:53:31,848 - TaskScriptRunner - INFO - Training with privacy (ε = 30.93, δ = 1e-05)
# 2025-03-02 23:53:32,276 - TaskScriptRunner - INFO - [1,  1500] loss: 1.812
# 2025-03-02 23:53:34,164 - TaskScriptRunner - INFO - Training with privacy (ε = 30.93, δ = 1e-05)
# 2025-03-02 23:53:34,568 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:53:35,995 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 49 %
# 2025-03-02 23:53:36,334 - IntimeModelSelector - INFO - validation metric 49 from client site-1
# 2025-03-02 23:53:36,464 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:53:37,844 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 49 %
# 2025-03-02 23:53:38,162 - IntimeModelSelector - INFO - validation metric 49 from client site-2
# 2025-03-02 23:53:38,310 - IntimeModelSelector - INFO - new best validation metric at round 10: 49.0
# 2025-03-02 23:53:38,313 - FedAvg - INFO - aggregating 2 update(s) at round 10
# 2025-03-02 23:53:38,315 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:53:38,318 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:53:38,318 - FedAvg - INFO - Round 11 started.
# 2025-03-02 23:53:38,318 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:53:38,319 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:53:38,447 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:53:38,448 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:53:38,448 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:53:38,449 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:53:38,534 - TaskScriptRunner - INFO - current_round=11, total_rounds=30
# 2025-03-02 23:53:40,125 - TaskScriptRunner - INFO - [1,   100] loss: 1.854
# 2025-03-02 23:53:40,262 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:53:40,263 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:53:40,263 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:53:40,264 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:53:40,368 - TaskScriptRunner - INFO - current_round=11, total_rounds=30
# 2025-03-02 23:53:41,998 - TaskScriptRunner - INFO - Training with privacy (ε = 31.05, δ = 1e-05)
# 2025-03-02 23:53:46,323 - TaskScriptRunner - INFO - [1,   100] loss: 1.772
# 2025-03-02 23:53:47,556 - TaskScriptRunner - INFO - [1,   200] loss: 1.766
# 2025-03-02 23:53:48,193 - TaskScriptRunner - INFO - Training with privacy (ε = 31.05, δ = 1e-05)
# 2025-03-02 23:53:51,043 - TaskScriptRunner - INFO - Training with privacy (ε = 31.13, δ = 1e-05)
# 2025-03-02 23:53:52,631 - TaskScriptRunner - INFO - [1,   200] loss: 1.779
# 2025-03-02 23:53:55,477 - TaskScriptRunner - INFO - [1,   300] loss: 1.752
# 2025-03-02 23:53:56,119 - TaskScriptRunner - INFO - Training with privacy (ε = 31.13, δ = 1e-05)
# 2025-03-02 23:53:59,074 - TaskScriptRunner - INFO - Training with privacy (ε = 31.21, δ = 1e-05)
# 2025-03-02 23:54:00,521 - TaskScriptRunner - INFO - [1,   300] loss: 1.765
# 2025-03-02 23:54:03,436 - TaskScriptRunner - INFO - [1,   400] loss: 1.825
# 2025-03-02 23:54:04,050 - TaskScriptRunner - INFO - Training with privacy (ε = 31.21, δ = 1e-05)
# 2025-03-02 23:54:06,900 - TaskScriptRunner - INFO - Training with privacy (ε = 31.28, δ = 1e-05)
# 2025-03-02 23:54:08,414 - TaskScriptRunner - INFO - [1,   400] loss: 1.737
# 2025-03-02 23:54:11,315 - TaskScriptRunner - INFO - [1,   500] loss: 1.749
# 2025-03-02 23:54:11,813 - TaskScriptRunner - INFO - Training with privacy (ε = 31.28, δ = 1e-05)
# 2025-03-02 23:54:14,683 - TaskScriptRunner - INFO - Training with privacy (ε = 31.36, δ = 1e-05)
# 2025-03-02 23:54:16,246 - TaskScriptRunner - INFO - [1,   500] loss: 1.805
# 2025-03-02 23:54:19,107 - TaskScriptRunner - INFO - [1,   600] loss: 1.769
# 2025-03-02 23:54:19,477 - TaskScriptRunner - INFO - Training with privacy (ε = 31.36, δ = 1e-05)
# 2025-03-02 23:54:22,693 - TaskScriptRunner - INFO - Training with privacy (ε = 31.44, δ = 1e-05)
# 2025-03-02 23:54:23,642 - TaskScriptRunner - INFO - [1,   600] loss: 1.780
# 2025-03-02 23:54:26,891 - TaskScriptRunner - INFO - [1,   700] loss: 1.791
# 2025-03-02 23:54:27,061 - TaskScriptRunner - INFO - Training with privacy (ε = 31.44, δ = 1e-05)
# 2025-03-02 23:54:30,041 - TaskScriptRunner - INFO - Training with privacy (ε = 31.51, δ = 1e-05)
# 2025-03-02 23:54:31,372 - TaskScriptRunner - INFO - [1,   700] loss: 1.814
# 2025-03-02 23:54:34,321 - TaskScriptRunner - INFO - [1,   800] loss: 1.823
# 2025-03-02 23:54:34,464 - TaskScriptRunner - INFO - Training with privacy (ε = 31.51, δ = 1e-05)
# 2025-03-02 23:54:36,155 - TaskScriptRunner - INFO - Training with privacy (ε = 31.59, δ = 1e-05)
# 2025-03-02 23:54:39,486 - TaskScriptRunner - INFO - [1,   800] loss: 1.778
# 2025-03-02 23:54:41,321 - TaskScriptRunner - INFO - Training with privacy (ε = 31.59, δ = 1e-05)
# 2025-03-02 23:54:41,477 - TaskScriptRunner - INFO - [1,   900] loss: 1.868
# 2025-03-02 23:54:44,869 - TaskScriptRunner - INFO - Training with privacy (ε = 31.66, δ = 1e-05)
# 2025-03-02 23:54:45,378 - TaskScriptRunner - INFO - [1,   900] loss: 1.802
# 2025-03-02 23:54:48,861 - TaskScriptRunner - INFO - Training with privacy (ε = 31.66, δ = 1e-05)
# 2025-03-02 23:54:48,960 - TaskScriptRunner - INFO - [1,  1000] loss: 1.789
# 2025-03-02 23:54:52,636 - TaskScriptRunner - INFO - [1,  1000] loss: 1.773
# 2025-03-02 23:54:55,314 - TaskScriptRunner - INFO - Training with privacy (ε = 31.74, δ = 1e-05)
# 2025-03-02 23:54:58,865 - TaskScriptRunner - INFO - Training with privacy (ε = 31.74, δ = 1e-05)
# 2025-03-02 23:54:59,137 - TaskScriptRunner - INFO - [1,  1100] loss: 1.806
# 2025-03-02 23:55:02,535 - TaskScriptRunner - INFO - Training with privacy (ε = 31.82, δ = 1e-05)
# 2025-03-02 23:55:02,813 - TaskScriptRunner - INFO - [1,  1100] loss: 1.834
# 2025-03-02 23:55:06,162 - TaskScriptRunner - INFO - Training with privacy (ε = 31.82, δ = 1e-05)
# 2025-03-02 23:55:06,603 - TaskScriptRunner - INFO - [1,  1200] loss: 1.816
# 2025-03-02 23:55:10,043 - TaskScriptRunner - INFO - Training with privacy (ε = 31.89, δ = 1e-05)
# 2025-03-02 23:55:10,120 - TaskScriptRunner - INFO - [1,  1200] loss: 1.835
# 2025-03-02 23:55:13,572 - TaskScriptRunner - INFO - Training with privacy (ε = 31.89, δ = 1e-05)
# 2025-03-02 23:55:14,034 - TaskScriptRunner - INFO - [1,  1300] loss: 1.799
# 2025-03-02 23:55:15,960 - TaskScriptRunner - INFO - Training with privacy (ε = 31.97, δ = 1e-05)
# 2025-03-02 23:55:18,696 - TaskScriptRunner - INFO - [1,  1300] loss: 1.809
# 2025-03-02 23:55:20,635 - TaskScriptRunner - INFO - Training with privacy (ε = 31.97, δ = 1e-05)
# 2025-03-02 23:55:21,094 - TaskScriptRunner - INFO - [1,  1400] loss: 1.782
# 2025-03-02 23:55:24,580 - TaskScriptRunner - INFO - [1,  1400] loss: 1.822
# 2025-03-02 23:55:24,586 - TaskScriptRunner - INFO - Training with privacy (ε = 32.04, δ = 1e-05)
# 2025-03-02 23:55:28,072 - TaskScriptRunner - INFO - Training with privacy (ε = 32.04, δ = 1e-05)
# 2025-03-02 23:55:28,599 - TaskScriptRunner - INFO - [1,  1500] loss: 1.808
# 2025-03-02 23:55:30,745 - TaskScriptRunner - INFO - Training with privacy (ε = 32.12, δ = 1e-05)
# 2025-03-02 23:55:33,039 - TaskScriptRunner - INFO - [1,  1500] loss: 1.775
# 2025-03-02 23:55:34,141 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:55:35,135 - TaskScriptRunner - INFO - Training with privacy (ε = 32.12, δ = 1e-05)
# 2025-03-02 23:55:35,516 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 49 %
# 2025-03-02 23:55:35,642 - IntimeModelSelector - INFO - validation metric 49 from client site-1
# 2025-03-02 23:55:36,316 - TaskScriptRunner - INFO - Finished Training
# 2025-03-02 23:55:37,699 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 49 %
# 2025-03-02 23:55:38,014 - IntimeModelSelector - INFO - validation metric 49 from client site-2
# 2025-03-02 23:55:38,365 - FedAvg - INFO - aggregating 2 update(s) at round 11
# 2025-03-02 23:55:38,368 - FedAvg - INFO - Start persist model on server.
# 2025-03-02 23:55:38,371 - FedAvg - INFO - End persist model on server.
# 2025-03-02 23:55:38,371 - FedAvg - INFO - Round 12 started.
# 2025-03-02 23:55:38,372 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-02 23:55:38,372 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-02 23:55:38,744 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:55:38,745 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:55:38,746 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:55:38,747 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:55:39,081 - TaskScriptRunner - INFO - current_round=12, total_rounds=30
# 2025-03-02 23:55:40,180 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-02 23:55:40,180 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-02 23:55:40,181 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-02 23:55:40,182 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-02 23:55:40,216 - TaskScriptRunner - INFO - current_round=12, total_rounds=30
# 2025-03-02 23:55:42,568 - TaskScriptRunner - INFO - [1,   100] loss: 1.797
# 2025-03-02 23:55:45,179 - TaskScriptRunner - INFO - [1,   100] loss: 1.785
# 2025-03-02 23:55:46,365 - TaskScriptRunner - INFO - Training with privacy (ε = 32.24, δ = 1e-05)
# 2025-03-02 23:55:48,871 - TaskScriptRunner - INFO - Training with privacy (ε = 32.24, δ = 1e-05)
# 2025-03-02 23:55:50,996 - TaskScriptRunner - INFO - [1,   200] loss: 1.827
# 2025-03-02 23:55:53,509 - TaskScriptRunner - INFO - [1,   200] loss: 1.782
# 2025-03-02 23:55:54,585 - TaskScriptRunner - INFO - Training with privacy (ε = 32.32, δ = 1e-05)
# 2025-03-02 23:55:57,148 - TaskScriptRunner - INFO - Training with privacy (ε = 32.32, δ = 1e-05)
# 2025-03-02 23:55:59,156 - TaskScriptRunner - INFO - [1,   300] loss: 1.762
# 2025-03-02 23:56:01,731 - TaskScriptRunner - INFO - [1,   300] loss: 1.802
# 2025-03-02 23:56:02,753 - TaskScriptRunner - INFO - Training with privacy (ε = 32.39, δ = 1e-05)
# 2025-03-02 23:56:05,389 - TaskScriptRunner - INFO - Training with privacy (ε = 32.39, δ = 1e-05)
# 2025-03-02 23:56:07,198 - TaskScriptRunner - INFO - [1,   400] loss: 1.723
# 2025-03-02 23:56:09,875 - TaskScriptRunner - INFO - [1,   400] loss: 1.888
# 2025-03-02 23:56:11,001 - TaskScriptRunner - INFO - Training with privacy (ε = 32.47, δ = 1e-05)
# 2025-03-02 23:56:13,670 - TaskScriptRunner - INFO - Training with privacy (ε = 32.47, δ = 1e-05)
# 2025-03-02 23:56:15,535 - TaskScriptRunner - INFO - [1,   500] loss: 1.803
# 2025-03-02 23:56:18,238 - TaskScriptRunner - INFO - [1,   500] loss: 1.742
# 2025-03-02 23:56:19,081 - TaskScriptRunner - INFO - Training with privacy (ε = 32.54, δ = 1e-05)
# 2025-03-02 23:56:22,015 - TaskScriptRunner - INFO - Training with privacy (ε = 32.54, δ = 1e-05)
# 2025-03-02 23:56:23,536 - TaskScriptRunner - INFO - [1,   600] loss: 1.818
# 2025-03-02 23:56:26,379 - TaskScriptRunner - INFO - [1,   600] loss: 1.756
# 2025-03-02 23:56:27,149 - TaskScriptRunner - INFO - Training with privacy (ε = 32.61, δ = 1e-05)
# 2025-03-02 23:56:29,993 - TaskScriptRunner - INFO - Training with privacy (ε = 32.61, δ = 1e-05)
# 2025-03-02 23:56:31,408 - TaskScriptRunner - INFO - [1,   700] loss: 1.765
# 2025-03-02 23:56:34,342 - TaskScriptRunner - INFO - [1,   700] loss: 1.785
# 2025-03-02 23:56:35,251 - TaskScriptRunner - INFO - Training with privacy (ε = 32.69, δ = 1e-05)
# 2025-03-02 23:56:38,260 - TaskScriptRunner - INFO - Training with privacy (ε = 32.69, δ = 1e-05)
# 2025-03-02 23:56:39,417 - TaskScriptRunner - INFO - [1,   800] loss: 1.737
# 2025-03-02 23:56:42,547 - TaskScriptRunner - INFO - [1,   800] loss: 1.797
# 2025-03-02 23:56:42,952 - TaskScriptRunner - INFO - Training with privacy (ε = 32.76, δ = 1e-05)
# 2025-03-02 23:56:46,109 - TaskScriptRunner - INFO - Training with privacy (ε = 32.76, δ = 1e-05)
# 2025-03-02 23:56:47,098 - TaskScriptRunner - INFO - [1,   900] loss: 1.837
# 2025-03-02 23:56:50,304 - TaskScriptRunner - INFO - [1,   900] loss: 1.807
# 2025-03-02 23:56:50,807 - TaskScriptRunner - INFO - Training with privacy (ε = 32.84, δ = 1e-05)
# 2025-03-02 23:56:54,016 - TaskScriptRunner - INFO - Training with privacy (ε = 32.84, δ = 1e-05)
# 2025-03-02 23:56:54,989 - TaskScriptRunner - INFO - [1,  1000] loss: 1.812
# 2025-03-02 23:56:58,129 - TaskScriptRunner - INFO - [1,  1000] loss: 1.756
# 2025-03-02 23:56:58,645 - TaskScriptRunner - INFO - Training with privacy (ε = 32.91, δ = 1e-05)
# 2025-03-02 23:57:01,908 - TaskScriptRunner - INFO - Training with privacy (ε = 32.91, δ = 1e-05)
# 2025-03-02 23:57:02,832 - TaskScriptRunner - INFO - [1,  1100] loss: 1.787
# 2025-03-02 23:57:05,994 - TaskScriptRunner - INFO - [1,  1100] loss: 1.854
# 2025-03-02 23:57:06,449 - TaskScriptRunner - INFO - Training with privacy (ε = 32.98, δ = 1e-05)
# 2025-03-02 23:57:09,616 - TaskScriptRunner - INFO - Training with privacy (ε = 32.98, δ = 1e-05)
# 2025-03-02 23:57:10,684 - TaskScriptRunner - INFO - [1,  1200] loss: 1.777
# 2025-03-02 23:57:13,803 - TaskScriptRunner - INFO - [1,  1200] loss: 1.865

# %% [markdown]
# ### 4. Global DP
# To implement Global DP, we can again use the `SVTPrivacy` Filter and add it this time to the outgoing global weights after aggregation on the server. This will reduce the amount of noise added to the training and is useful when we don't need to protect the client's updates from a potentially malicious server, such as in the case when using homomorphic encryption or trusted execution environments for secure aggregation.
#
# > **Note:** Use `filter_type=FilterType.TASK_DATA` as we add the filter to the global model before sending it to clients.

# %%
from nvflare import FilterType
from nvflare.client.config import TransferType
from nvflare.app_common.filters import SVTPrivacy

# Create BaseFedJob with the initial model
job = BaseFedJob(
  name="cifar10_fedavg_gdp",
  initial_model=Net(),
)

# Define the controller and send to server
controller = FedAvg(
    num_clients=n_clients,
    num_rounds=100,  # 100 rounds should converge
)
job.to_server(controller)

# add privacy filter on server 
dp_filter = SVTPrivacy(fraction=0.9, epsilon=0.1, noise_var=0.1, gamma=1e-5)
job.to_server(dp_filter, tasks=["train"], filter_type=FilterType.TASK_DATA)


# Add clients
for i in range(n_clients):
    runner = ScriptRunner(
        script="src/cifar10_fl.py",
        params_transfer_type=TransferType.DIFF
    )
    job.to(runner, f"site-{i+1}")

# Optionally export the configuration
job.export_job("job_configs")

# %% [markdown]
# and start the training using the simulator call.

# %%
job.simulator_run(f"/tmp/nvflare/{job.name}")
# Out:
# 2025-03-03 00:25:55,956 - IntimeModelSelector - INFO - model selection weights control: {}
# 2025-03-03 00:25:57,272 - TBAnalyticsReceiver - INFO - Tensorboard records can be found in /tmp/nvflare/cifar10_fedavg_gdp/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/cifar10_fedavg_gdp/server/simulate_job/tb_events`
# 2025-03-03 00:25:57,273 - FedAvg - INFO - Initializing BaseModelController workflow.
# 2025-03-03 00:25:57,274 - FedAvg - INFO - Beginning model controller run.
# 2025-03-03 00:25:57,275 - FedAvg - INFO - Start FedAvg.
# 2025-03-03 00:25:57,275 - FedAvg - INFO - loading initial model from persistor
# 2025-03-03 00:25:57,275 - PTFileModelPersistor - INFO - Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2025-03-03 00:25:57,276 - FedAvg - INFO - Round 0 started.
# 2025-03-03 00:25:57,276 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:25:57,277 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:26:02,008 - TaskScriptRunner - INFO - start task run() with full path: /tmp/nvflare/cifar10_fedavg_gdp/site-2/simulate_job/app_site-2/custom/src/cifar10_fl.py
# 2025-03-03 00:26:02,010 - TaskScriptRunner - INFO - start task run() with full path: /tmp/nvflare/cifar10_fedavg_gdp/site-1/simulate_job/app_site-1/custom/src/cifar10_fl.py
# 2025-03-03 00:26:02,021 - SVTPrivacy - INFO - Delta_w: Max abs: 0.11537224054336548, Min abs: 1.2040138699376257e-06, Median abs: 0.027939461171627045.
# 2025-03-03 00:26:02,021 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 0.0002734994184992117, clip gamma: 1e-05
# 2025-03-03 00:26:02,022 - SVTPrivacy - INFO - Delta_w: Max abs: 0.11537224054336548, Min abs: 1.2040138699376257e-06, Median abs: 0.027939461171627045.
# 2025-03-03 00:26:02,025 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -0.0003595777917940749, clip gamma: 1e-05
# 2025-03-03 00:26:02,028 - SVTPrivacy - INFO - selected 30208 responses, requested 55806.0
# 2025-03-03 00:26:02,034 - SVTPrivacy - INFO - selected 32514 responses, requested 55806.0
# 2025-03-03 00:26:02,035 - SVTPrivacy - INFO - selected 45578 responses, requested 55806.0
# 2025-03-03 00:26:02,038 - SVTPrivacy - INFO - selected 47656 responses, requested 55806.0
# 2025-03-03 00:26:02,038 - SVTPrivacy - INFO - selected 53517 responses, requested 55806.0
# 2025-03-03 00:26:02,041 - SVTPrivacy - INFO - selected 55103 responses, requested 55806.0
# 2025-03-03 00:26:02,041 - SVTPrivacy - INFO - selected 57610 responses, requested 55806.0
# 2025-03-03 00:26:02,048 - SVTPrivacy - INFO - selected 58645 responses, requested 55806.0
# 2025-03-03 00:26:02,056 - SVTPrivacy - INFO - noise max: 0.0022476927380002715, median 0.00013718380092831396
# 2025-03-03 00:26:02,074 - SVTPrivacy - INFO - noise max: 0.0021228244909242103, median 0.0001373804137963736
# 2025-03-03 00:26:02,145 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:02,147 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:02,147 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:02,148 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:02,149 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:02,149 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:02,150 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:02,151 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:04,249 - TaskScriptRunner - INFO - Running on device cuda
# 2025-03-03 00:26:04,260 - TaskScriptRunner - INFO - Running on device cuda
# 2025-03-03 00:26:05,665 - TaskScriptRunner - INFO - current_round=0, total_rounds=100
# 2025-03-03 00:26:05,699 - TaskScriptRunner - INFO - current_round=0, total_rounds=100
# 2025-03-03 00:26:06,894 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:06,904 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:07,246 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:26:07,257 - TaskScriptRunner - INFO - [1,   200] loss: 2.304
# 2025-03-03 00:26:07,597 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:26:07,609 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:26:07,941 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:26:07,950 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:26:08,295 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:26:08,340 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:26:08,718 - TaskScriptRunner - INFO - [1,   600] loss: 2.304
# 2025-03-03 00:26:08,779 - TaskScriptRunner - INFO - [1,   600] loss: 2.304
# 2025-03-03 00:26:09,167 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:26:09,220 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:26:09,613 - TaskScriptRunner - INFO - [1,   800] loss: 2.304
# 2025-03-03 00:26:09,664 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:26:10,055 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:26:10,103 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:26:10,500 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:26:10,547 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:26:10,942 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:26:10,985 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:26:11,384 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:26:11,424 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:26:11,821 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:26:11,860 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:26:12,266 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:26:12,292 - TaskScriptRunner - INFO - [1,  1400] loss: 2.302
# 2025-03-03 00:26:12,715 - TaskScriptRunner - INFO - [1,  1500] loss: 2.304
# 2025-03-03 00:26:12,731 - TaskScriptRunner - INFO - [1,  1500] loss: 2.304
# 2025-03-03 00:26:13,081 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:13,086 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:14,247 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:14,321 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:15,363 - FedAvg - INFO - aggregating 2 update(s) at round 0
# 2025-03-03 00:26:15,365 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:26:15,369 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:26:15,369 - FedAvg - INFO - Round 1 started.
# 2025-03-03 00:26:15,370 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:26:15,370 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:26:17,101 - SVTPrivacy - INFO - Delta_w: Max abs: 0.12188874185085297, Min abs: 1.2040138699376257e-06, Median abs: 0.027938248589634895.
# 2025-03-03 00:26:17,101 - SVTPrivacy - INFO - Delta_w: Max abs: 0.12188874185085297, Min abs: 1.2040138699376257e-06, Median abs: 0.027938248589634895.
# 2025-03-03 00:26:17,102 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 6.980501511033811e-05, clip gamma: 1e-05
# 2025-03-03 00:26:17,102 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -0.000423955593871631, clip gamma: 1e-05
# 2025-03-03 00:26:17,109 - SVTPrivacy - INFO - selected 30871 responses, requested 55806.0
# 2025-03-03 00:26:17,113 - SVTPrivacy - INFO - selected 32371 responses, requested 55806.0
# 2025-03-03 00:26:17,113 - SVTPrivacy - INFO - selected 46276 responses, requested 55806.0
# 2025-03-03 00:26:17,116 - SVTPrivacy - INFO - selected 47894 responses, requested 55806.0
# 2025-03-03 00:26:17,117 - SVTPrivacy - INFO - selected 54025 responses, requested 55806.0
# 2025-03-03 00:26:17,119 - SVTPrivacy - INFO - selected 55180 responses, requested 55806.0
# 2025-03-03 00:26:17,119 - SVTPrivacy - INFO - selected 57976 responses, requested 55806.0
# 2025-03-03 00:26:17,125 - SVTPrivacy - INFO - selected 58760 responses, requested 55806.0
# 2025-03-03 00:26:17,136 - SVTPrivacy - INFO - noise max: 0.0023792022798265586, median 0.00013786017234719252
# 2025-03-03 00:26:17,161 - SVTPrivacy - INFO - noise max: 0.0020513786434286792, median 0.00013836694568329029
# 2025-03-03 00:26:17,183 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:17,184 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:17,184 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:17,185 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:17,221 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:17,222 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:17,222 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:17,223 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:17,276 - TaskScriptRunner - INFO - current_round=1, total_rounds=100
# 2025-03-03 00:26:17,344 - TaskScriptRunner - INFO - current_round=1, total_rounds=100
# 2025-03-03 00:26:17,842 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:17,945 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:18,288 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:26:18,390 - TaskScriptRunner - INFO - [1,   200] loss: 2.304
# 2025-03-03 00:26:18,728 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:26:18,831 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:26:19,171 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:26:19,275 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:26:19,614 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:26:19,714 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:26:20,052 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:26:20,150 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:26:20,488 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:26:20,592 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:26:20,928 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:26:21,038 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:26:21,374 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:26:21,559 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:26:21,821 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:26:22,074 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:26:22,267 - TaskScriptRunner - INFO - [1,  1100] loss: 2.304
# 2025-03-03 00:26:22,594 - TaskScriptRunner - INFO - [1,  1100] loss: 2.304
# 2025-03-03 00:26:22,718 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:26:23,096 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:26:23,165 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:26:23,595 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:26:23,612 - TaskScriptRunner - INFO - [1,  1400] loss: 2.304
# 2025-03-03 00:26:24,057 - TaskScriptRunner - INFO - [1,  1500] loss: 2.304
# 2025-03-03 00:26:24,098 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:26:24,390 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:24,555 - TaskScriptRunner - INFO - [1,  1500] loss: 2.304
# 2025-03-03 00:26:24,880 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:25,617 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:25,715 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:26:26,076 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:26,254 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:26:26,649 - IntimeModelSelector - INFO - new best validation metric at round 1: 10.0
# 2025-03-03 00:26:26,652 - FedAvg - INFO - aggregating 2 update(s) at round 1
# 2025-03-03 00:26:26,654 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:26:26,657 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:26:26,657 - FedAvg - INFO - Round 2 started.
# 2025-03-03 00:26:26,658 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:26:26,658 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:26:27,861 - SVTPrivacy - INFO - Delta_w: Max abs: 0.11537224054336548, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:26:27,862 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 6.0465771539733914e-05, clip gamma: 1e-05
# 2025-03-03 00:26:27,869 - SVTPrivacy - INFO - selected 30817 responses, requested 55806.0
# 2025-03-03 00:26:27,872 - SVTPrivacy - INFO - selected 46318 responses, requested 55806.0
# 2025-03-03 00:26:27,874 - SVTPrivacy - INFO - selected 53962 responses, requested 55806.0
# 2025-03-03 00:26:27,876 - SVTPrivacy - INFO - selected 58010 responses, requested 55806.0
# 2025-03-03 00:26:27,887 - SVTPrivacy - INFO - noise max: 0.0022493243573951265, median 0.00013840220413258479
# 2025-03-03 00:26:27,929 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:27,929 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:27,930 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:27,931 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:28,140 - TaskScriptRunner - INFO - current_round=2, total_rounds=100
# 2025-03-03 00:26:28,403 - SVTPrivacy - INFO - Delta_w: Max abs: 0.11537224054336548, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:26:28,403 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -0.000168923611806227, clip gamma: 1e-05
# 2025-03-03 00:26:28,410 - SVTPrivacy - INFO - selected 31659 responses, requested 55806.0
# 2025-03-03 00:26:28,414 - SVTPrivacy - INFO - selected 47125 responses, requested 55806.0
# 2025-03-03 00:26:28,416 - SVTPrivacy - INFO - selected 54707 responses, requested 55806.0
# 2025-03-03 00:26:28,417 - SVTPrivacy - INFO - selected 58487 responses, requested 55806.0
# 2025-03-03 00:26:28,429 - SVTPrivacy - INFO - noise max: 0.002738570868761485, median 0.0001385726555076984
# 2025-03-03 00:26:28,475 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:28,475 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:28,476 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:28,477 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:28,597 - TaskScriptRunner - INFO - current_round=2, total_rounds=100
# 2025-03-03 00:26:28,667 - TaskScriptRunner - INFO - [1,   100] loss: 2.304
# 2025-03-03 00:26:29,089 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:26:29,228 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:29,524 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:26:29,711 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:26:29,959 - TaskScriptRunner - INFO - [1,   400] loss: 2.304
# 2025-03-03 00:26:30,193 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:26:30,392 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:26:30,669 - TaskScriptRunner - INFO - [1,   400] loss: 2.304
# 2025-03-03 00:26:30,831 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:26:31,152 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:26:31,262 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:26:31,637 - TaskScriptRunner - INFO - [1,   600] loss: 2.304
# 2025-03-03 00:26:31,693 - TaskScriptRunner - INFO - [1,   800] loss: 2.304
# 2025-03-03 00:26:32,114 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:26:32,125 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:26:32,560 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:26:32,588 - TaskScriptRunner - INFO - [1,   800] loss: 2.302
# 2025-03-03 00:26:32,992 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:26:33,067 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:26:33,429 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:26:33,544 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:26:33,864 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:26:34,024 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:26:34,299 - TaskScriptRunner - INFO - [1,  1400] loss: 2.304
# 2025-03-03 00:26:34,503 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:26:34,735 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:26:34,982 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:26:35,066 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:35,410 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:26:35,836 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:26:36,160 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:36,267 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:36,463 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:26:37,334 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:37,509 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:26:37,648 - FedAvg - INFO - aggregating 2 update(s) at round 2
# 2025-03-03 00:26:37,653 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:26:37,656 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:26:37,657 - FedAvg - INFO - Round 3 started.
# 2025-03-03 00:26:37,657 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:26:37,658 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:26:38,612 - SVTPrivacy - INFO - Delta_w: Max abs: 0.12813931703567505, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:26:38,612 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 5.380009068648823e-05, clip gamma: 1e-05
# 2025-03-03 00:26:38,619 - SVTPrivacy - INFO - selected 30748 responses, requested 55806.0
# 2025-03-03 00:26:38,623 - SVTPrivacy - INFO - selected 46420 responses, requested 55806.0
# 2025-03-03 00:26:38,625 - SVTPrivacy - INFO - selected 54221 responses, requested 55806.0
# 2025-03-03 00:26:38,626 - SVTPrivacy - INFO - selected 58165 responses, requested 55806.0
# 2025-03-03 00:26:38,638 - SVTPrivacy - INFO - noise max: 0.0020117816631153775, median 0.00013802037808344182
# 2025-03-03 00:26:38,680 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:38,681 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:38,681 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:38,683 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:38,793 - TaskScriptRunner - INFO - current_round=3, total_rounds=100
# 2025-03-03 00:26:39,400 - TaskScriptRunner - INFO - [1,   100] loss: 2.304
# 2025-03-03 00:26:39,664 - SVTPrivacy - INFO - Delta_w: Max abs: 0.12813931703567505, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:26:39,665 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 2.4052148790212765e-05, clip gamma: 1e-05
# 2025-03-03 00:26:39,672 - SVTPrivacy - INFO - selected 31166 responses, requested 55806.0
# 2025-03-03 00:26:39,676 - SVTPrivacy - INFO - selected 46719 responses, requested 55806.0
# 2025-03-03 00:26:39,678 - SVTPrivacy - INFO - selected 54401 responses, requested 55806.0
# 2025-03-03 00:26:39,680 - SVTPrivacy - INFO - selected 58135 responses, requested 55806.0
# 2025-03-03 00:26:39,691 - SVTPrivacy - INFO - noise max: 0.002496959671489781, median 0.00013752992019627037
# 2025-03-03 00:26:39,738 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:39,739 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:39,740 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:39,741 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:39,851 - TaskScriptRunner - INFO - current_round=3, total_rounds=100
# 2025-03-03 00:26:39,878 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:26:40,278 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:26:40,469 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:40,707 - TaskScriptRunner - INFO - [1,   400] loss: 2.304
# 2025-03-03 00:26:40,977 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:26:41,138 - TaskScriptRunner - INFO - [1,   500] loss: 2.302
# 2025-03-03 00:26:41,486 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:26:41,567 - TaskScriptRunner - INFO - [1,   600] loss: 2.304
# 2025-03-03 00:26:41,992 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:26:41,996 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:26:42,429 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:26:42,496 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:26:42,873 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:26:42,999 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:26:43,317 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:26:43,502 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:26:43,758 - TaskScriptRunner - INFO - [1,  1100] loss: 2.302
# 2025-03-03 00:26:44,010 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:26:44,201 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:26:44,518 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:26:44,673 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:26:45,023 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:26:45,181 - TaskScriptRunner - INFO - [1,  1400] loss: 2.305
# 2025-03-03 00:26:45,526 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:26:45,685 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:26:46,036 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:26:46,052 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:46,387 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:26:46,758 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:26:47,179 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:26:47,215 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:47,457 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:47,714 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:26:48,599 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:48,772 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:26:49,107 - FedAvg - INFO - aggregating 2 update(s) at round 3
# 2025-03-03 00:26:49,109 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:26:49,112 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:26:49,112 - FedAvg - INFO - Round 4 started.
# 2025-03-03 00:26:49,113 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:26:49,113 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:26:49,865 - SVTPrivacy - INFO - Delta_w: Max abs: 0.1571042537689209, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:26:49,866 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 4.709318309248401e-06, clip gamma: 1e-05
# 2025-03-03 00:26:49,873 - SVTPrivacy - INFO - selected 31106 responses, requested 55806.0
# 2025-03-03 00:26:49,876 - SVTPrivacy - INFO - selected 46636 responses, requested 55806.0
# 2025-03-03 00:26:49,878 - SVTPrivacy - INFO - selected 54314 responses, requested 55806.0
# 2025-03-03 00:26:49,879 - SVTPrivacy - INFO - selected 58168 responses, requested 55806.0
# 2025-03-03 00:26:49,891 - SVTPrivacy - INFO - noise max: 0.0023104739425680726, median 0.0001380568263644697
# 2025-03-03 00:26:49,936 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:49,937 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:49,937 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:49,938 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:50,234 - TaskScriptRunner - INFO - current_round=4, total_rounds=100
# 2025-03-03 00:26:50,726 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:50,921 - SVTPrivacy - INFO - Delta_w: Max abs: 0.1571042537689209, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:26:50,921 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -0.0003950186473347921, clip gamma: 1e-05
# 2025-03-03 00:26:50,928 - SVTPrivacy - INFO - selected 32197 responses, requested 55806.0
# 2025-03-03 00:26:50,932 - SVTPrivacy - INFO - selected 47791 responses, requested 55806.0
# 2025-03-03 00:26:50,934 - SVTPrivacy - INFO - selected 55209 responses, requested 55806.0
# 2025-03-03 00:26:50,935 - SVTPrivacy - INFO - selected 58755 responses, requested 55806.0
# 2025-03-03 00:26:50,947 - SVTPrivacy - INFO - noise max: 0.0020885727179504408, median 0.0001398252102270718
# 2025-03-03 00:26:50,991 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:26:50,992 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:26:50,992 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:26:50,993 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:26:51,122 - TaskScriptRunner - INFO - current_round=4, total_rounds=100
# 2025-03-03 00:26:51,136 - TaskScriptRunner - INFO - [1,   200] loss: 2.304
# 2025-03-03 00:26:51,508 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:26:51,605 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:26:51,982 - TaskScriptRunner - INFO - [1,   400] loss: 2.304
# 2025-03-03 00:26:52,034 - TaskScriptRunner - INFO - [1,   200] loss: 2.304
# 2025-03-03 00:26:52,474 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:26:52,479 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:26:52,908 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:26:52,977 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:26:53,348 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:26:53,476 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:26:53,785 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:26:53,975 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:26:54,221 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:26:54,476 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:26:54,658 - TaskScriptRunner - INFO - [1,   800] loss: 2.304
# 2025-03-03 00:26:54,977 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:26:55,095 - TaskScriptRunner - INFO - [1,   900] loss: 2.302
# 2025-03-03 00:26:55,477 - TaskScriptRunner - INFO - [1,  1100] loss: 2.304
# 2025-03-03 00:26:55,536 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:26:55,978 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:26:55,983 - TaskScriptRunner - INFO - [1,  1100] loss: 2.304
# 2025-03-03 00:26:56,428 - TaskScriptRunner - INFO - [1,  1200] loss: 2.302
# 2025-03-03 00:26:56,481 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:26:56,868 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:26:56,982 - TaskScriptRunner - INFO - [1,  1400] loss: 2.304
# 2025-03-03 00:26:57,308 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:26:57,483 - TaskScriptRunner - INFO - [1,  1500] loss: 2.302
# 2025-03-03 00:26:57,748 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:26:57,853 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:58,081 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:26:59,059 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:59,317 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:26:59,470 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:26:59,579 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:26:59,966 - FedAvg - INFO - aggregating 2 update(s) at round 4
# 2025-03-03 00:26:59,968 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:26:59,971 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:26:59,971 - FedAvg - INFO - Round 5 started.
# 2025-03-03 00:26:59,972 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:26:59,972 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:27:01,580 - SVTPrivacy - INFO - Delta_w: Max abs: 0.17943544685840607, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:27:01,580 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -0.00010958984067494891, clip gamma: 1e-05
# 2025-03-03 00:27:01,588 - SVTPrivacy - INFO - selected 31242 responses, requested 55806.0
# 2025-03-03 00:27:01,591 - SVTPrivacy - INFO - selected 46823 responses, requested 55806.0
# 2025-03-03 00:27:01,594 - SVTPrivacy - INFO - selected 54477 responses, requested 55806.0
# 2025-03-03 00:27:01,595 - SVTPrivacy - INFO - selected 58253 responses, requested 55806.0
# 2025-03-03 00:27:01,606 - SVTPrivacy - INFO - noise max: 0.0021860649346448187, median 0.00013826013596599987
# 2025-03-03 00:27:01,651 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:01,652 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:01,653 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:01,654 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:01,683 - SVTPrivacy - INFO - Delta_w: Max abs: 0.17943544685840607, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:27:01,684 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 4.550062558833285e-06, clip gamma: 1e-05
# 2025-03-03 00:27:01,693 - SVTPrivacy - INFO - selected 30717 responses, requested 55806.0
# 2025-03-03 00:27:01,697 - SVTPrivacy - INFO - selected 46326 responses, requested 55806.0
# 2025-03-03 00:27:01,699 - SVTPrivacy - INFO - selected 54048 responses, requested 55806.0
# 2025-03-03 00:27:01,700 - SVTPrivacy - INFO - selected 58019 responses, requested 55806.0
# 2025-03-03 00:27:01,712 - SVTPrivacy - INFO - noise max: 0.0019445516945785024, median 0.00013893002646601672
# 2025-03-03 00:27:01,760 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:01,761 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:01,761 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:01,762 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:01,838 - TaskScriptRunner - INFO - current_round=5, total_rounds=100
# 2025-03-03 00:27:02,079 - TaskScriptRunner - INFO - current_round=5, total_rounds=100
# 2025-03-03 00:27:02,385 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:02,550 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:02,762 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:27:02,997 - TaskScriptRunner - INFO - [1,   200] loss: 2.304
# 2025-03-03 00:27:03,133 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:27:03,438 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:27:03,506 - TaskScriptRunner - INFO - [1,   400] loss: 2.304
# 2025-03-03 00:27:03,881 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:03,930 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:27:04,322 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:27:04,401 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:27:04,762 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:27:04,873 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:27:05,204 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:27:05,339 - TaskScriptRunner - INFO - [1,   800] loss: 2.304
# 2025-03-03 00:27:05,650 - TaskScriptRunner - INFO - [1,   800] loss: 2.304
# 2025-03-03 00:27:05,830 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:27:06,092 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:27:06,310 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:27:06,531 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:27:06,780 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:27:06,972 - TaskScriptRunner - INFO - [1,  1100] loss: 2.304
# 2025-03-03 00:27:07,235 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:27:07,414 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:27:07,688 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:27:07,857 - TaskScriptRunner - INFO - [1,  1300] loss: 2.302
# 2025-03-03 00:27:08,142 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:27:08,301 - TaskScriptRunner - INFO - [1,  1400] loss: 2.305
# 2025-03-03 00:27:08,599 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:08,742 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:08,951 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:09,073 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:10,191 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:10,226 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:10,294 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:27:10,692 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:27:10,790 - FedAvg - INFO - aggregating 2 update(s) at round 5
# 2025-03-03 00:27:10,792 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:27:10,795 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:27:10,795 - FedAvg - INFO - Round 6 started.
# 2025-03-03 00:27:10,796 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:27:10,796 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:27:12,398 - SVTPrivacy - INFO - Delta_w: Max abs: 0.19662980735301971, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:27:12,398 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -8.304287384966655e-05, clip gamma: 1e-05
# 2025-03-03 00:27:12,406 - SVTPrivacy - INFO - selected 31135 responses, requested 55806.0
# 2025-03-03 00:27:12,410 - SVTPrivacy - INFO - selected 46588 responses, requested 55806.0
# 2025-03-03 00:27:12,412 - SVTPrivacy - INFO - selected 54509 responses, requested 55806.0
# 2025-03-03 00:27:12,413 - SVTPrivacy - INFO - selected 58279 responses, requested 55806.0
# 2025-03-03 00:27:12,424 - SVTPrivacy - INFO - noise max: 0.0024627746101237324, median 0.0001388483196493439
# 2025-03-03 00:27:12,470 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:12,471 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:12,471 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:12,472 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:12,708 - TaskScriptRunner - INFO - current_round=6, total_rounds=100
# 2025-03-03 00:27:12,795 - SVTPrivacy - INFO - Delta_w: Max abs: 0.19662980735301971, Min abs: 1.2040138699376257e-06, Median abs: 0.027937287464737892.
# 2025-03-03 00:27:12,795 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 0.000426526864518054, clip gamma: 1e-05
# 2025-03-03 00:27:12,813 - SVTPrivacy - INFO - selected 29789 responses, requested 55806.0
# 2025-03-03 00:27:12,816 - SVTPrivacy - INFO - selected 45314 responses, requested 55806.0
# 2025-03-03 00:27:12,817 - SVTPrivacy - INFO - selected 53286 responses, requested 55806.0
# 2025-03-03 00:27:12,818 - SVTPrivacy - INFO - selected 57444 responses, requested 55806.0
# 2025-03-03 00:27:12,827 - SVTPrivacy - INFO - noise max: 0.0021440512867660732, median 0.00013950719730861672
# 2025-03-03 00:27:12,865 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:12,866 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:12,866 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:12,867 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:13,244 - TaskScriptRunner - INFO - current_round=6, total_rounds=100
# 2025-03-03 00:27:13,293 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:13,717 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:27:13,808 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:14,220 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:27:14,247 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:27:14,681 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:27:14,727 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:15,115 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:15,243 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:27:15,547 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:27:15,758 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:27:15,978 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:27:16,277 - TaskScriptRunner - INFO - [1,   700] loss: 2.302
# 2025-03-03 00:27:16,408 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:27:16,797 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:27:16,843 - TaskScriptRunner - INFO - [1,   800] loss: 2.304
# 2025-03-03 00:27:17,274 - TaskScriptRunner - INFO - [1,   900] loss: 2.302
# 2025-03-03 00:27:17,317 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:27:17,703 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:27:17,831 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:27:18,138 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:27:18,353 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:27:18,576 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:27:18,867 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:27:19,016 - TaskScriptRunner - INFO - [1,  1300] loss: 2.302
# 2025-03-03 00:27:19,377 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:27:19,457 - TaskScriptRunner - INFO - [1,  1400] loss: 2.305
# 2025-03-03 00:27:19,884 - TaskScriptRunner - INFO - [1,  1400] loss: 2.304
# 2025-03-03 00:27:19,898 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:20,228 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:20,365 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:20,657 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:21,416 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:21,852 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:21,902 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:27:22,008 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:27:22,307 - FedAvg - INFO - aggregating 2 update(s) at round 6
# 2025-03-03 00:27:22,309 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:27:22,312 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:27:22,312 - FedAvg - INFO - Round 7 started.
# 2025-03-03 00:27:22,312 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:27:22,313 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:27:24,012 - SVTPrivacy - INFO - Delta_w: Max abs: 0.2519312798976898, Min abs: 1.2040138699376257e-06, Median abs: 0.027937738224864006.
# 2025-03-03 00:27:24,013 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -0.0003032158569504502, clip gamma: 1e-05
# 2025-03-03 00:27:24,017 - SVTPrivacy - INFO - selected 31849 responses, requested 55806.0
# 2025-03-03 00:27:24,019 - SVTPrivacy - INFO - selected 47315 responses, requested 55806.0
# 2025-03-03 00:27:24,020 - SVTPrivacy - INFO - selected 54831 responses, requested 55806.0
# 2025-03-03 00:27:24,020 - SVTPrivacy - INFO - selected 58578 responses, requested 55806.0
# 2025-03-03 00:27:24,026 - SVTPrivacy - INFO - noise max: 0.002064391446532828, median 0.00013729779636897292
# 2025-03-03 00:27:24,055 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:24,056 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:24,057 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:24,058 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:24,121 - SVTPrivacy - INFO - Delta_w: Max abs: 0.2519312798976898, Min abs: 1.2040138699376257e-06, Median abs: 0.027937738224864006.
# 2025-03-03 00:27:24,121 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 0.000353413194670332, clip gamma: 1e-05
# 2025-03-03 00:27:24,129 - SVTPrivacy - INFO - selected 29891 responses, requested 55806.0
# 2025-03-03 00:27:24,133 - SVTPrivacy - INFO - selected 45466 responses, requested 55806.0
# 2025-03-03 00:27:24,135 - SVTPrivacy - INFO - selected 53420 responses, requested 55806.0
# 2025-03-03 00:27:24,136 - SVTPrivacy - INFO - selected 57582 responses, requested 55806.0
# 2025-03-03 00:27:24,149 - SVTPrivacy - INFO - noise max: 0.00240292302036199, median 0.00013789271256699285
# 2025-03-03 00:27:24,198 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:24,199 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:24,200 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:24,201 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:24,369 - TaskScriptRunner - INFO - current_round=7, total_rounds=100
# 2025-03-03 00:27:24,444 - TaskScriptRunner - INFO - current_round=7, total_rounds=100
# 2025-03-03 00:27:24,878 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:25,037 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:25,236 - TaskScriptRunner - INFO - [1,   200] loss: 2.304
# 2025-03-03 00:27:25,482 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:27:25,594 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:27:25,925 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:27:25,951 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:26,305 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:27:26,369 - TaskScriptRunner - INFO - [1,   400] loss: 2.304
# 2025-03-03 00:27:26,662 - TaskScriptRunner - INFO - [1,   600] loss: 2.304
# 2025-03-03 00:27:26,809 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:27:27,018 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:27:27,248 - TaskScriptRunner - INFO - [1,   600] loss: 2.304
# 2025-03-03 00:27:27,386 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:27:27,680 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:27:27,752 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:27:28,114 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:27:28,121 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:27:28,492 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:27:28,548 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:27:28,865 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:27:28,984 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:27:29,238 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:27:29,420 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:27:29,614 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:27:29,858 - TaskScriptRunner - INFO - [1,  1200] loss: 2.304
# 2025-03-03 00:27:29,990 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:30,282 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:30,307 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:27:30,711 - TaskScriptRunner - INFO - [1,  1400] loss: 2.304
# 2025-03-03 00:27:31,145 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:31,478 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:31,498 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:31,730 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:27:32,653 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:33,104 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:27:33,409 - FedAvg - INFO - aggregating 2 update(s) at round 7
# 2025-03-03 00:27:33,411 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:27:33,415 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:27:33,415 - FedAvg - INFO - Round 8 started.
# 2025-03-03 00:27:33,415 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:27:33,416 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:27:33,827 - SVTPrivacy - INFO - Delta_w: Max abs: 0.1969735026359558, Min abs: 1.2040138699376257e-06, Median abs: 0.027938248589634895.
# 2025-03-03 00:27:33,828 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 0.0005242511358780428, clip gamma: 1e-05
# 2025-03-03 00:27:33,835 - SVTPrivacy - INFO - selected 29380 responses, requested 55806.0
# 2025-03-03 00:27:33,839 - SVTPrivacy - INFO - selected 44784 responses, requested 55806.0
# 2025-03-03 00:27:33,841 - SVTPrivacy - INFO - selected 52878 responses, requested 55806.0
# 2025-03-03 00:27:33,842 - SVTPrivacy - INFO - selected 57151 responses, requested 55806.0
# 2025-03-03 00:27:33,854 - SVTPrivacy - INFO - noise max: 0.0020039505071039574, median 0.00013984108831581989
# 2025-03-03 00:27:33,899 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:33,900 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:33,901 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:33,902 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:34,019 - TaskScriptRunner - INFO - current_round=8, total_rounds=100
# 2025-03-03 00:27:34,584 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:34,998 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:27:35,224 - SVTPrivacy - INFO - Delta_w: Max abs: 0.1969735026359558, Min abs: 1.2040138699376257e-06, Median abs: 0.027938248589634895.
# 2025-03-03 00:27:35,224 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = -7.095151829997034e-05, clip gamma: 1e-05
# 2025-03-03 00:27:35,232 - SVTPrivacy - INFO - selected 31349 responses, requested 55806.0
# 2025-03-03 00:27:35,235 - SVTPrivacy - INFO - selected 46817 responses, requested 55806.0
# 2025-03-03 00:27:35,237 - SVTPrivacy - INFO - selected 54390 responses, requested 55806.0
# 2025-03-03 00:27:35,238 - SVTPrivacy - INFO - selected 58239 responses, requested 55806.0
# 2025-03-03 00:27:35,250 - SVTPrivacy - INFO - noise max: 0.0024546139891053315, median 0.00013928825075525114
# 2025-03-03 00:27:35,295 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:35,296 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:35,296 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:35,297 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:35,411 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:27:35,684 - TaskScriptRunner - INFO - current_round=8, total_rounds=100
# 2025-03-03 00:27:35,821 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:36,196 - TaskScriptRunner - INFO - [1,   500] loss: 2.303
# 2025-03-03 00:27:36,328 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:36,630 - TaskScriptRunner - INFO - [1,   600] loss: 2.302
# 2025-03-03 00:27:36,840 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:27:37,066 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:27:37,347 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:27:37,510 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:27:37,838 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:37,952 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:27:38,277 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:27:38,396 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:27:38,756 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:27:38,844 - TaskScriptRunner - INFO - [1,  1100] loss: 2.305
# 2025-03-03 00:27:39,255 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:27:39,291 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:27:39,732 - TaskScriptRunner - INFO - [1,  1300] loss: 2.304
# 2025-03-03 00:27:39,758 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:27:40,177 - TaskScriptRunner - INFO - [1,  1400] loss: 2.304
# 2025-03-03 00:27:40,259 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:27:40,619 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:40,762 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:27:40,957 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:41,213 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:27:41,626 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:27:42,041 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:27:42,161 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:42,409 - TaskScriptRunner - INFO - [1,  1400] loss: 2.304
# 2025-03-03 00:27:42,431 - IntimeModelSelector - INFO - validation metric 10 from client site-2
# 2025-03-03 00:27:42,751 - TaskScriptRunner - INFO - [1,  1500] loss: 2.303
# 2025-03-03 00:27:43,027 - TaskScriptRunner - INFO - Finished Training
# 2025-03-03 00:27:44,262 - TaskScriptRunner - INFO - Accuracy of the network on the 10000 test images: 10 %
# 2025-03-03 00:27:44,330 - IntimeModelSelector - INFO - validation metric 10 from client site-1
# 2025-03-03 00:27:44,435 - FedAvg - INFO - aggregating 2 update(s) at round 8
# 2025-03-03 00:27:44,437 - FedAvg - INFO - Start persist model on server.
# 2025-03-03 00:27:44,440 - FedAvg - INFO - End persist model on server.
# 2025-03-03 00:27:44,441 - FedAvg - INFO - Round 9 started.
# 2025-03-03 00:27:44,441 - FedAvg - INFO - Sampled clients: ['site-1', 'site-2']
# 2025-03-03 00:27:44,442 - FedAvg - INFO - Sending task train to ['site-1', 'site-2']
# 2025-03-03 00:27:44,547 - SVTPrivacy - INFO - Delta_w: Max abs: 0.18237392604351044, Min abs: 1.2040138699376257e-06, Median abs: 0.027939461171627045.
# 2025-03-03 00:27:44,547 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 0.00013696628760588646, clip gamma: 1e-05
# 2025-03-03 00:27:44,554 - SVTPrivacy - INFO - selected 30595 responses, requested 55806.0
# 2025-03-03 00:27:44,558 - SVTPrivacy - INFO - selected 45964 responses, requested 55806.0
# 2025-03-03 00:27:44,560 - SVTPrivacy - INFO - selected 53903 responses, requested 55806.0
# 2025-03-03 00:27:44,561 - SVTPrivacy - INFO - selected 57963 responses, requested 55806.0
# 2025-03-03 00:27:44,572 - SVTPrivacy - INFO - noise max: 0.002311949229649694, median 0.00013983809576631468
# 2025-03-03 00:27:44,618 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:44,618 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:44,619 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:44,620 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:44,678 - TaskScriptRunner - INFO - current_round=9, total_rounds=100
# 2025-03-03 00:27:45,200 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:45,616 - TaskScriptRunner - INFO - [1,   200] loss: 2.303
# 2025-03-03 00:27:46,026 - TaskScriptRunner - INFO - [1,   300] loss: 2.304
# 2025-03-03 00:27:46,438 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:46,441 - SVTPrivacy - INFO - Delta_w: Max abs: 0.18237392604351044, Min abs: 1.2040138699376257e-06, Median abs: 0.027939461171627045.
# 2025-03-03 00:27:46,441 - SVTPrivacy - INFO - total params: 62006, epsilon: 0.1, perparam budget 1.7919220155538832e-06, threshold tau: 1e-06 + f(eps_1) = 8.068600976882566e-05, clip gamma: 1e-05
# 2025-03-03 00:27:46,449 - SVTPrivacy - INFO - selected 30826 responses, requested 55806.0
# 2025-03-03 00:27:46,452 - SVTPrivacy - INFO - selected 46249 responses, requested 55806.0
# 2025-03-03 00:27:46,455 - SVTPrivacy - INFO - selected 54054 responses, requested 55806.0
# 2025-03-03 00:27:46,456 - SVTPrivacy - INFO - selected 58049 responses, requested 55806.0
# 2025-03-03 00:27:46,468 - SVTPrivacy - INFO - noise max: 0.0021109018649590914, median 0.00013832344658962133
# 2025-03-03 00:27:46,511 - PTInProcessClientAPIExecutor - INFO - execute for task (train)
# 2025-03-03 00:27:46,512 - PTInProcessClientAPIExecutor - INFO - send data to peer
# 2025-03-03 00:27:46,512 - PTInProcessClientAPIExecutor - INFO - sending payload to peer
# 2025-03-03 00:27:46,513 - PTInProcessClientAPIExecutor - INFO - Waiting for result from peer
# 2025-03-03 00:27:46,780 - TaskScriptRunner - INFO - current_round=9, total_rounds=100
# 2025-03-03 00:27:46,857 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:27:47,268 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:27:47,349 - TaskScriptRunner - INFO - [1,   100] loss: 2.303
# 2025-03-03 00:27:47,708 - TaskScriptRunner - INFO - [1,   700] loss: 2.304
# 2025-03-03 00:27:47,790 - TaskScriptRunner - INFO - [1,   200] loss: 2.304
# 2025-03-03 00:27:48,152 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:27:48,225 - TaskScriptRunner - INFO - [1,   300] loss: 2.303
# 2025-03-03 00:27:48,594 - TaskScriptRunner - INFO - [1,   900] loss: 2.303
# 2025-03-03 00:27:48,661 - TaskScriptRunner - INFO - [1,   400] loss: 2.303
# 2025-03-03 00:27:49,037 - TaskScriptRunner - INFO - [1,  1000] loss: 2.304
# 2025-03-03 00:27:49,101 - TaskScriptRunner - INFO - [1,   500] loss: 2.304
# 2025-03-03 00:27:49,484 - TaskScriptRunner - INFO - [1,  1100] loss: 2.303
# 2025-03-03 00:27:49,536 - TaskScriptRunner - INFO - [1,   600] loss: 2.303
# 2025-03-03 00:27:49,923 - TaskScriptRunner - INFO - [1,  1200] loss: 2.303
# 2025-03-03 00:27:49,971 - TaskScriptRunner - INFO - [1,   700] loss: 2.303
# 2025-03-03 00:27:50,368 - TaskScriptRunner - INFO - [1,  1300] loss: 2.303
# 2025-03-03 00:27:50,472 - TaskScriptRunner - INFO - [1,   800] loss: 2.303
# 2025-03-03 00:27:50,815 - TaskScriptRunner - INFO - [1,  1400] loss: 2.303
# 2025-03-03 00:27:50,975 - TaskScriptRunner - INFO - [1,   900] loss: 2.304
# 2025-03-03 00:27:51,268 - TaskScriptRunner - INFO - [1,  1500] loss: 2.304
# 2025-03-03 00:27:51,474 - TaskScriptRunner - INFO - [1,  1000] loss: 2.303
# 2025-03-03 00:27:51,616 - TaskScriptRunner - INFO - Finished Training

# %% [markdown]
# ## 5. Visualize the results
# Finally, you can plot the results by running `tensorboard --logdir /tmp/nvflare` in a new terminal. In this notebook, we only run for a few FL rounds for simplicity. If you uncomment the recommended number of in the FedAvg controller definitions of the cells, you can run the experiments until convergence. As one can observe, the model with DP (red) takes more rounds to achieve a comparable training performance but has less risks of leaking private information compared to the model trained without DP (orange). For more details, on how to apply this filter in a medical imaging use case, see [Li et al. 2019](https://arxiv.org/abs/1910.00962) [1].
#
# ![TensorBoard Training curve of FedAvg without and with DP](tb_curve_dp.png)

# %% [markdown]
# ### Summary
# This notebook explores two methods for adding Differential Privacy (DP) noise to model training: using an NVFlare `Filter` or integrating Opacus within your local training script. These approaches enhance privacy by reducing the risk of memorizing individual data points.
#
# DP remains an active research area, and the optimal choice of parameters depends on your specific problem and risk tolerance. A smaller epsilon provides stronger privacy but introduces more noise, potentially lowering accuracy. This trade-off should be carefully navigated. A recommended technique from [Opacus](https://opacus.ai/tutorials/building_image_classifier#Tips-and-Tricks) is to pre-train on public data before fine-tuning on private data.
#
# Further research into quantifying model memorization and data leakage during training can provide deeper insights into privacy risks. For more details, refer to our paper on [gradient inversion](../../../../../../research/quantifying-data-leakage/README.md) [[4]](https://arxiv.org/abs/2202.06924) which is available in NVFlare.
#
# For training large language models with DP, refer to the latest Opacus examples, which can be seamlessly integrated into NVFlare deployments. If you are using TensorFlow, you can achieve similar privacy protections with [TensorFlow Privacy](https://www.tensorflow.org/responsible_ai/privacy/guide).

# %% [markdown]
# #### References
# [1] Li, W., Milletarì, F., Xu, D., Rieke, N., Hancox, J., Zhu, W., Baust, M., Cheng, Y., Ourselin, S., Cardoso, M.J. and Feng, A., 2019, October. Privacy-preserving federated brain tumour segmentation. In International workshop on machine learning in medical imaging (pp. 133-141). Springer, Cham.
#
# [2] Lyu, M., Su, D., & Li, N. (2016). Understanding the sparse vector technique for differential privacy. arXiv preprint arXiv:1603.01699.
#
# [3] Abadi, M., Chu, A., Goodfellow, I., McMahan, H. B., Mironov, I., Talwar, K., & Zhang, L. (2016, October). Deep learning with differential privacy. In Proceedings of the 2016 ACM SIGSAC conference on computer and communications security (pp. 308-318).
#
# [4] Hatamizadeh, A., Yin, H., Molchanov, P., Myronenko, A., Li, W., Dogra, P., ... & Roth, H. R. (2023). Do gradient inversion attacks make federated learning unsafe?. IEEE Transactions on Medical Imaging, 42(7), 2044-2056.
