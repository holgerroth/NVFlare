# %% [markdown]
# # Federated Deep Learning for Financial Fraud Detection using TensorFlow
#
# This notebook demonstrates how to implement federated learning for financial fraud detection using NVIDIA FLARE (NVFlare). The notebook shows a complete workflow for training a deep learning model across multiple clients while maintaining data privacy.
#
# ## 0. Define User Info
# Update the user information based on your details and the MLFlow server provided.

# %%
#startup_kit_location = "/path/to/admin_startup_kit"
startup_kit_location = "/home/hroth/Code/finance_poc/admin"
username = "admin@nvidia.com"

# MLFlow tracking info
mlflow_tracking_uri = "https://rrayrz6j-nvflmlflowserver.xenon.lepton.run"

# %% [markdown]
# ## 1. Define Recipe
#
# By default, we can use a small randomly generated dataset to illustrate the workflow. If the full sythentic dataset should be used, please provide the filepath with the `--dataset` train argument.

# %%
from src.pt.model import SimpleNetwork

from nvflare.app_opt.pt.recipes.fedavg import FedAvgRecipe
from nvflare.recipe.sim_env import SimEnv
from nvflare.recipe.prod_env import ProdEnv

num_rounds = 10

recipe = FedAvgRecipe(
    name="hello-pt-mlflow",
    min_clients=1,
    num_rounds=num_rounds,
    initial_model=SimpleNetwork(num_classes=2),
    train_script="src/pt/client.py",
    train_args="--data_path None --epochs 2" # /workspace/dataset/paysim1"  # assume each client uses the same directory path; `None` uses randomly generated data
)
# Out:
# 2025-09-17 17:48:38.217639: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-17 17:48:38.266043: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-17 17:48:39.128637: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ### Add Experiment Tracking
# We can add a central MLFlow tracker where clients can report their training progress.

# %%
from nvflare.recipe.utils import add_experiment_tracking

add_experiment_tracking(recipe, tracking_type="mlflow", tracking_config={"tracking_uri": mlflow_tracking_uri})

# %% [markdown]
# ### Add filter to collect SHAP metrics on the server
# We add a filter to the server to collect the incoming SHAP metrics reported by the clients.

# %%
from src.pt.utils import ShapCollectionFilter
shap_filter = ShapCollectionFilter()
recipe.add_server_input_filter(shap_filter, tasks=["train"])

# optionally export
recipe.export("job_configs")

# %% [markdown]
# ## 2. (Optionally) Run in Simulation Environment

# %%
#env = SimEnv(num_clients=1)
#recipe.execute(env=env)

# %% [markdown]
# ## 3. Run in Production Environment

# %%
env = ProdEnv(startup_kit_location=startup_kit_location, username=username)
run = recipe.execute(env=env)
# Out:
# Connecting to FLARE ...
# Submitted job 'hello-pt-mlflow' with ID: 44a4137d-4373-4e2f-a416-fd13dce9884f

# %% [markdown]
# ### Get Status

# %%
print("Job Status is:", run.get_status())
# Out:
# Connecting to FLARE ...
# Job Status is: RUNNING

# %% [markdown]
# ### Get Results

# %%
result_path = run.get_result()
print("Result can be found in:", result_path)
# Out:
# Connecting to FLARE ...
# Job ID:  44a4137d-4373-4e2f-a416-fd13dce9884f
# Job Meta:  {'name': 'hello-pt-mlflow', 'resource_spec': {}, 'min_clients': 1, 'deploy_map': {'app': ['@ALL']}, 'byoc': True, 'submitter_name': 'admin@nvidia.com', 'submitter_org': 'nvidia', 'submitter_role': 'project_admin', 'job_folder_name': 'hello-pt-mlflow', 'job_id': '44a4137d-4373-4e2f-a416-fd13dce9884f', 'submit_time': 1758145723.8177683, 'submit_time_iso': '2025-09-17T21:48:43.817768+00:00', 'start_time': '2025-09-17 21:48:46.486105', 'duration': 'N/A', 'data_storage_format': 2, 'status': 'RUNNING', 'job_deploy_detail': ['server: OK', 'site5: OK'], 'schedule_count': 1, 'last_schedule_time': 1758145724.8304913, 'schedule_history': ['2025-09-17 21:48:44: scheduled']}
# ......................
# {'name': 'hello-pt-mlflow', 'resource_spec': {}, 'min_clients': 1, 'deploy_map': {'app': ['@ALL']}, 'byoc': True, 'submitter_name': 'admin@nvidia.com', 'submitter_org': 'nvidia', 'submitter_role': 'project_admin', 'job_folder_name': 'hello-pt-mlflow', 'job_id': '44a4137d-4373-4e2f-a416-fd13dce9884f', 'submit_time': 1758145723.8177683, 'submit_time_iso': '2025-09-17T21:48:43.817768+00:00', 'start_time': '2025-09-17 21:48:46.486105', 'duration': '0:00:54.485849', 'data_storage_format': 2, 'status': 'FINISHED:COMPLETED', 'job_deploy_detail': ['server: OK', 'site5: OK'], 'schedule_count': 1, 'last_schedule_time': 1758145724.8304913, 'schedule_history': ['2025-09-17 21:48:44: scheduled']}
# job monitor done: rc=<MonitorReturnCode.JOB_FINISHED: 0>
# Result can be found in: /home/hroth/Code/finance_poc/admin/transfer/44a4137d-4373-4e2f-a416-fd13dce9884f

# %% [markdown]
# ### Visualization of Training Progress
#
# In the meantime, you can check the progress via mlflow: [https://rrayrz6j-nvflmlflowserver.xenon.lepton.run](https://rrayrz6j-nvflmlflowserver.xenon.lepton.run)
#
# The mflow metrics should show the accuracy progressing at each round:
#
# ![mlflow model metrics](./figs/mlflow.png)

# %% [markdown]
# ### Optionally Abort Job
# If you'd like to stop the job before completion for any reason, you can run:

# %%
#run.abort()

# %% [markdown]
# ### 4. Visualize SHAP metrics
# In this example, the server collects the clients' SHAP metrics at each round and saves them to a file. After downloading the training artifacts from the server (using `run.get_result()`), we can access them here and plot the results.

# %%
shap_metrics_file = result_path + "/workspace/app_server/shap_values.npy"
client = "site5"
num_round = num_rounds - 1

import matplotlib.pyplot as plt
# %matplotlib inline

from src.pt.utils import plot_shap_summary, plot_shap_feature_importance, load_shap_metrics

all_shap_metrics = load_shap_metrics(shap_metrics_file)
print(f"All SHAP metrics: {all_shap_metrics.keys()}")

shap_metrics = all_shap_metrics[f"round{num_round}"][client]
print(f"SHAP metrics for round 0 and site-1: {shap_metrics.keys()}")
# Out:
# Error loading SHAP metrics from /home/hroth/Code/finance_poc/admin/transfer/44a4137d-4373-4e2f-a416-fd13dce9884f/workspace/app_server/shap_values.npy: [Errno 2] No such file or directory: '/home/hroth/Code/finance_poc/admin/transfer/44a4137d-4373-4e2f-a416-fd13dce9884f/workspace/app_server/shap_values.npy'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 11
#       8 from src.pt.utils import plot_shap_summary, plot_shap_feature_importance, load_shap_metrics
#      10 all_shap_metrics = load_shap_metrics(shap_metrics_file)
# ---> 11 print(f"All SHAP metrics: {all_shap_metrics.keys()}")
#      13 shap_metrics = all_shap_metrics[f"round{num_round}"][client]
#      14 print(f"SHAP metrics for round 0 and site-1: {shap_metrics.keys()}")
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %% [markdown]
# #### Show summary plot

# %%
plot_shap_summary(shap_metrics)
plt.title(f"SHAP Values Round {num_round} for Client {client}")
plt.show()

# %% [markdown]
# #### Show feature importance plot

# %%
plot_shap_feature_importance(shap_metrics)
plt.title(f"Feature Importance Round {num_round} for Client {client}")
plt.show()
